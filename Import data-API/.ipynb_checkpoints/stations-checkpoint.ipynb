# %%
from pathlib import Path
import pandas as pd
import pprint
import os

# %%
csv_stations = Path("../Resources/stationslist.csv")
stations_df = pd.read_csv(csv_stations,low_memory=False)
stations_df['Lat'] = pd.to_numeric(stations_df['Lat'], errors='coerce')
stations_df['Long'] = pd.to_numeric(stations_df['Long'], errors='coerce')
stations_df
# Out:
#      Site No. Station Type                                            Address  \
# 0      509398   Rain_gauge                       BALLAJURA DRAIN AT BALLAJURA
# 1      509417   Rain_gauge                WOODBRIDGE CREEK AT BROWN PARK (P1)
# 2      509452   Rain_gauge          LESMURDIE BROOK  AT ORANGEDALE ROAD (P9)
# 3      509460   Rain_gauge                    POISON GULLY AT MAIDA VALE (P6)
# 4      509573   Rain_gauge                           LIGHT ST B.D. AT MORLEY
# ..        ...          ...                                                ...
# 247  D2001327        Level  Denny Av BD - B015(adjacent to Kelmscott Bapti...
# 248  D2001333        Level            South St MD - A004 (South St/South Tce)
# 249  D2001336        Level       Bennett St MD - A004 (Bennett St/Terrace Rd)
# 250  D2001473        Level                  Subiaco MD - X006 (Churchill Ave)
# 251  D2001855        Level             Crawley BD- C007 (Clifton St Nedlands)
#
#           Lat       Long  Status                      Team
# 0   -31.82423  115.87203  Active  Catchment & Environments
# 1   -31.89140  116.05243  Active  Catchment & Environments
# 2   -32.00513  116.06026  Active  Catchment & Environments
# 3   -31.94756  116.06026  Active  Catchment & Environments
# 4   -31.88917  115.88889  Active  Catchment & Environments
# ..        ...        ...     ...                       ...
# 247 -32.11809  116.01172  Active                Conveyance
# 248 -32.06368  115.75246  Active                Conveyance
# 249 -31.96117  115.87054  Active                Conveyance
# 250 -31.94789  115.82753  Active                Conveyance
# 251 -31.97676  115.81171  Active                Conveyance
#
# [252 rows x 7 columns]

# %%
# Initialize a dictionary to store dictionaries for each station
all_stations = {}

# Iterate through each row
for index, row in stations_df.iterrows():
    
    # Use the station ID as the key in the dictionary
    station_id = str(row['Site No.'])
    
     # Read the CSV file for the current rain station into a DataFrame
    # csv_rain_station = Path(f"../Resources/{station_id}.csv")
    # rain_station_df = pd.read_csv(csv_rain_station, low_memory=False)
    # r_station_df = rain_station_df.transpose()
    
    station_dict = {
        "Sitno": row['Site No.'],
        "StationId": row['Station Type'],
        "lat": row['Lat'],
        "lon": row['Long'],
        "status": row['Status'],
        "address": row['Address'],
        "team": row['Team'],
        # "Date": r_station_df.iloc[0].tolist(),
        # "amount": r_station_df.iloc[1].tolist(),
        # "Quality": r_station_df.iloc[2].tolist()
    }
    
    # Update the all_stations dictionary with the station_dict
    all_stations[station_id] = station_dict
all_stations
# Out:
# {'509398': {'Sitno': '509398',
#   'StationId': 'Rain_gauge',
#   'lat': -31.82423,
#   'lon': 115.87203,
#   'status': 'Active',
#   'address': 'BALLAJURA DRAIN AT BALLAJURA',
#   'team': 'Catchment & Environments'},
#  '509417': {'Sitno': '509417',
#   'StationId': 'Rain_gauge',
#   'lat': -31.8914,
#   'lon': 116.05243,
#   'status': 'Active',
#   'address': 'WOODBRIDGE CREEK AT BROWN PARK (P1)',
#   'team': 'Catchment & Environments'},
#  '509452': {'Sitno': '509452',
#   'StationId': 'Rain_gauge',
#   'lat': -32.00513,
#   'lon': 116.06026,
#   'status': 'Active',
#   'address': 'LESMURDIE BROOK  AT ORANGEDALE ROAD (P9) ',
#   'team': 'Catchment & Environments'},
#  '509460': {'Sitno': '509460',
#   'StationId': 'Rain_gauge',
#   'lat': -31.94756,
#   'lon': 116.06026,
#   'status': 'Active',
#   'address': 'POISON GULLY AT MAIDA VALE (P6)',
#   'team': 'Catchment & Environments'},
#  '509573': {'Sitno': '509573',
#   'StationId': 'Rain_gauge',
#   'lat': -31.88917,
#   'lon': 115.88889,
#   'status': 'Active',
#   'address': 'LIGHT ST B.D. AT MORLEY ',
#   'team': 'Catchment & Environments'},
#  '509574': {'Sitno': '509574',
#   'StationId': 'Rain_gauge',
#   'lat': -32.04753,
#   'lon': 115.84215,
#   'status': 'Active',
#   'address': 'BOORAGOON LAKE INFLOW  AT PINEY LAKES RESERVE ',
#   'team': 'Catchment & Environments'},
#  '509583': {'Sitno': '509583',
#   'StationId': 'Rain_gauge',
#   'lat': -32.11757,
#   'lon': 115.77916,
#   'status': 'Inactive',
#   'address': 'MARKET GARDEN SWAMPS AT PACKHAM 1B DRAIN ',
#   'team': 'Catchment & Environments'},
#  '509593': {'Sitno': '509593',
#   'StationId': 'Rain_gauge',
#   'lat': -32.0558,
#   'lon': 115.75392,
#   'status': 'fault',
#   'address': 'ESSEX ST MD AT FREMANTLE JAIL ',
#   'team': 'Catchment & Environments'},
#  '509702': {'Sitno': '509702',
#   'StationId': 'Rain_gauge',
#   'lat': -32.28389,
#   'lon': 115.76167,
#   'status': 'Active',
#   'address': 'ROCKINGHAM MAIN DRAIN AT WENDO COURT',
#   'team': 'Catchment & Environments'},
#  '509704': {'Sitno': '509704',
#   'StationId': 'Rain_gauge',
#   'lat': -31.89972,
#   'lon': 115.76667,
#   'status': 'Active',
#   'address': 'COLIN RD MAIN DRAIN AT COLIN RD COMP BASIN ',
#   'team': 'Catchment & Environments'},
#  '509451': {'Sitno': '509451',
#   'StationId': 'Rain_gauge',
#   'lat': -32.04167,
#   'lon': 115.9775,
#   'status': 'Active',
#   'address': 'BICKLEY BROOK AT AUSTIN AVENUE (P10) ',
#   'team': 'Catchment & Environments'},
#  '509458': {'Sitno': '509458',
#   'StationId': 'Rain_gauge',
#   'lat': -32.00361,
#   'lon': 115.97694,
#   'status': 'Active',
#   'address': 'WOODLUPINE BROOK AT WELSHPOOL (P8) ',
#   'team': 'Catchment & Environments'},
#  '509459': {'Sitno': '509459',
#   'StationId': 'Rain_gauge',
#   'lat': -32.14961,
#   'lon': 116.0206,
#   'status': 'Active',
#   'address': 'NEERIGEN BROOK AT ARMADALE (P5)',
#   'team': 'Catchment & Environments'},
#  '509703': {'Sitno': '509703',
#   'StationId': 'Rain_gauge',
#   'lat': -31.99611,
#   'lon': 115.9175,
#   'status': 'Active',
#   'address': 'MILLS ST MAIN DRAIN AT ELLAM ST EAST COMPENSATING BASIN',
#   'team': 'Catchment & Environments'},
#  'W0034613': {'Sitno': 'W0034613',
#   'StationId': 'Rain_gauge',
#   'lat': -31.95803,
#   'lon': 115.84148,
#   'status': 'Active',
#   'address': 'MT ELIZA FRASER AV KINGS PARK',
#   'team': 'Catchment & Environments'},
#  '616015': {'Sitno': '616015',
#   'StationId': 'GSTN',
#   'lat': -31.95366,
#   'lon': 116.00671,
#   'status': 'Active',
#   'address': 'POISON GULLY CREEK AT LITTLEFIELD RD',
#   'team': 'Catchment & Environments'},
#  '616042': {'Sitno': '616042',
#   'StationId': 'GSTN',
#   'lat': -32.02528,
#   'lon': 115.96722,
#   'status': 'Active',
#   'address': 'YULE BROOK MAIN DRAIN AT BRIXTON STREET',
#   'team': 'Catchment & Environments'},
#  '616043': {'Sitno': '616043',
#   'StationId': 'GSTN',
#   'lat': -32.01644,
#   'lon': 115.91949,
#   'status': 'Inactive',
#   'address': 'MILL ST MAIN DRAIN AT PALM PLACE',
#   'team': 'Catchment & Environments'},
#  '616044': {'Sitno': '616044',
#   'StationId': 'GSTN',
#   'lat': -32.15,
#   'lon': 116.01083,
#   'status': 'fault',
#   'address': 'NEERIGEN BROOK MAIN DRAIN AT ABBEY ROAD',
#   'team': 'Catchment & Environments'},
#  '616045': {'Sitno': '616045',
#   'StationId': 'GSTN',
#   'lat': -31.939,
#   'lon': 115.87895,
#   'status': 'Active',
#   'address': 'MT LAWLEY MAIN DRAIN AT MT LAWLEY',
#   'team': 'Catchment & Environments'},
#  '616046': {'Sitno': '616046',
#   'StationId': 'GSTN',
#   'lat': -31.99872,
#   'lon': 115.98939,
#   'status': 'Active',
#   'address': 'WOODLUPINE BROOK AT HARTFIELD PARK',
#   'team': 'Catchment & Environments'},
#  '616047': {'Sitno': '616047',
#   'StationId': 'GSTN',
#   'lat': -32.04306,
#   'lon': 115.9762,
#   'status': 'Active',
#   'address': 'BICKLEY BROOK MAIN DRAIN AT AUSTIN AVE',
#   'team': 'Catchment & Environments'},
#  '6556W003': {'Sitno': '6556W003',
#   'StationId': 'IWSS',
#   'lat': -31.86117,
#   'lon': 116.27796,
#   'status': 'Active',
#   'address': '163 Willcox St Chidlow',
#   'team': 'Conveyance'},
#  '6055W032': {'Sitno': '6055W032',
#   'StationId': 'IWSS',
#   'lat': -31.90005,
#   'lon': 115.97432,
#   'status': 'Active',
#   'address': 'HUBERT ST H20 GUILDFORD',
#   'team': 'Conveyance'},
#  '6056W033': {'Sitno': '6056W033',
#   'StationId': 'IWSS',
#   'lat': -31.83663,
#   'lon': 116.03753,
#   'status': 'Active',
#   'address': '179 Gugeri Rd Herne Hill',
#   'team': 'Conveyance'},
#  '6072W001': {'Sitno': '6072W001',
#   'StationId': 'IWSS',
#   'lat': -31.91377,
#   'lon': 116.13303,
#   'status': 'Active',
#   'address': '100 THORNBILL PL Mahogany Creek',
#   'team': 'Conveyance'},
#  '6082W002': {'Sitno': '6082W002',
#   'StationId': 'IWSS',
#   'lat': -31.86654,
#   'lon': 116.22089,
#   'status': 'Active',
#   'address': '9 Buckland Gr Mt Helena',
#   'team': 'Conveyance'},
#  '6081W008': {'Sitno': '6081W008',
#   'StationId': 'IWSS',
#   'lat': -31.87286,
#   'lon': 116.14739,
#   'status': 'Active',
#   'address': '20 Vista Dr Parkerville',
#   'team': 'Conveyance'},
#  '6074W002': {'Sitno': '6074W002',
#   'StationId': 'IWSS',
#   'lat': -31.88742,
#   'lon': 116.22292,
#   'status': 'Active',
#   'address': '660 LANCE ST Sawyers Valley',
#   'team': 'Conveyance'},
#  '6056W004': {'Sitno': '6056W004',
#   'StationId': 'IWSS',
#   'lat': -31.86739,
#   'lon': 116.04897,
#   'status': 'Active',
#   'address': '39 Campolino Gardens Stratton',
#   'team': 'Conveyance'},
#  '6053W001': {'Sitno': '6053W001',
#   'StationId': 'IWSS',
#   'lat': -31.90903,
#   'lon': 115.90232,
#   'status': 'Active',
#   'address': '15 Bay View St Bayswater',
#   'team': 'Conveyance'},
#  '6055W008': {'Sitno': '6055W008',
#   'StationId': 'IWSS',
#   'lat': -31.86067,
#   'lon': 115.97373,
#   'status': 'Active',
#   'address': '147 Arthur St Dayton',
#   'team': 'Conveyance'},
#  '6055W029': {'Sitno': '6055W029',
#   'StationId': 'IWSS',
#   'lat': -31.84919,
#   'lon': 115.97786,
#   'status': 'Active',
#   'address': '5 Sapphire Rd Dayton',
#   'team': 'Conveyance'},
#  '6055W028': {'Sitno': '6055W028',
#   'StationId': 'IWSS',
#   'lat': -31.85136,
#   'lon': 115.97169,
#   'status': 'Active',
#   'address': '152 Cranleigh St Dayton',
#   'team': 'Conveyance'},
#  '6000W031': {'Sitno': '6000W031',
#   'StationId': 'IWSS',
#   'lat': -31.95844,
#   'lon': 115.86734,
#   'status': 'Active',
#   'address': '231 Adelaide Tce East Perth',
#   'team': 'Conveyance'},
#  '6004W016': {'Sitno': '6004W016',
#   'StationId': 'IWSS',
#   'lat': -31.9551,
#   'lon': 115.88028,
#   'status': 'Active',
#   'address': '28 Trafalgar Rd East Perth',
#   'team': 'Conveyance'},
#  '6018W016': {'Sitno': '6018W016',
#   'StationId': 'IWSS',
#   'lat': -31.87751,
#   'lon': 115.78258,
#   'status': 'Active',
#   'address': '42 Paine Court Karrinyup',
#   'team': 'Conveyance'},
#  '6062W019': {'Sitno': '6062W019',
#   'StationId': 'IWSS',
#   'lat': -31.87764,
#   'lon': 115.91309,
#   'status': 'Active',
#   'address': '3B Mcpherson Ave  Noranda',
#   'team': 'Conveyance'},
#  '6019W005': {'Sitno': '6019W005',
#   'StationId': 'IWSS',
#   'lat': -31.88927,
#   'lon': 115.76259,
#   'status': 'Inactive',
#   'address': '3 Sackville Terrace Scarborough',
#   'team': 'Conveyance'},
#  '6037W004': {'Sitno': '6037W004',
#   'StationId': 'IWSS',
#   'lat': -31.50376,
#   'lon': 115.60786,
#   'status': 'fault',
#   'address': 'TWO ROCKS AT 102 ASHMORE AV',
#   'team': 'Conveyance'},
#  '6025W053': {'Sitno': '6025W053',
#   'StationId': 'IWSS',
#   'lat': -31.81299,
#   'lon': 115.7498,
#   'status': 'Active',
#   'address': 'HILLARYS OP 25 RAE Pl',
#   'team': 'Conveyance'},
#  '6035W024': {'Sitno': '6035W024',
#   'StationId': 'IWSS',
#   'lat': -31.54399,
#   'lon': 115.65465,
#   'status': 'Active',
#   'address': '8 Birdie Gr Yanchep',
#   'team': 'Conveyance'},
#  '6035W025': {'Sitno': '6035W025',
#   'StationId': 'IWSS',
#   'lat': -31.53604,
#   'lon': 115.63367,
#   'status': 'Active',
#   'address': '19 Chittick Way Yanchep',
#   'team': 'Conveyance'},
#  '6035W010': {'Sitno': '6035W010',
#   'StationId': 'IWSS',
#   'lat': -31.54243,
#   'lon': 115.64781,
#   'status': 'Active',
#   'address': '62 Moorpark Av Yanchep',
#   'team': 'Conveyance'},
#  '6063W009': {'Sitno': '6063W009',
#   'StationId': 'IWSS',
#   'lat': -31.85682,
#   'lon': 115.95613,
#   'status': 'Active',
#   'address': '1 CHAMAELEON RD Bennett Springs',
#   'team': 'Conveyance'},
#  '6063W004': {'Sitno': '6063W004',
#   'StationId': 'IWSS',
#   'lat': -31.85764,
#   'lon': 115.93518,
#   'status': 'Inactive',
#   'address': '127 Bennett Springs Dr Bennett Springs',
#   'team': 'Conveyance'},
#  '6063W010': {'Sitno': '6063W010',
#   'StationId': 'IWSS',
#   'lat': -31.8569,
#   'lon': 115.91827,
#   'status': 'fault',
#   'address': 'BENNETT SPRINGS AT 57 MITRA LOOP',
#   'team': 'Conveyance'},
#  '6055W026': {'Sitno': '6055W026',
#   'StationId': 'IWSS',
#   'lat': -31.81443,
#   'lon': 115.97788,
#   'status': 'Active',
#   'address': '121 Pannage Way Brabham',
#   'team': 'Conveyance'},
#  '6055W027': {'Sitno': '6055W027',
#   'StationId': 'IWSS',
#   'lat': -31.81445,
#   'lon': 115.96442,
#   'status': 'Active',
#   'address': '11 BILDERSEE AV Brabham',
#   'team': 'Conveyance'},
#  '6084W011': {'Sitno': '6084W011',
#   'StationId': 'IWSS',
#   'lat': -31.67317,
#   'lon': 116.02944,
#   'status': 'Active',
#   'address': '15 CORVETTE RD  BULLSBROOK',
#   'team': 'Conveyance'},
#  '6084W010': {'Sitno': '6084W010',
#   'StationId': 'IWSS',
#   'lat': -31.65944,
#   'lon': 116.04559,
#   'status': 'Active',
#   'address': 'H66 HURD RD BULLSBROOK',
#   'team': 'Conveyance'},
#  '6055W030': {'Sitno': '6055W030',
#   'StationId': 'IWSS',
#   'lat': -31.86636,
#   'lon': 115.9586,
#   'status': 'Active',
#   'address': 'OPP 218 Patricia St Caversham',
#   'team': 'Conveyance'},
#  '6069W027': {'Sitno': '6069W027',
#   'StationId': 'IWSS',
#   'lat': -31.62435,
#   'lon': 115.69595,
#   'status': 'Active',
#   'address': '35 Charlottes Vista  Ellenbrook',
#   'team': 'Conveyance'},
#  '6069W028': {'Sitno': '6069W028',
#   'StationId': 'IWSS',
#   'lat': -31.74789,
#   'lon': 115.98098,
#   'status': 'Active',
#   'address': '109 Pineroo Terrace  Ellenbrook',
#   'team': 'Conveyance'},
#  '6069W033': {'Sitno': '6069W033',
#   'StationId': 'IWSS',
#   'lat': -31.74569,
#   'lon': 115.99923,
#   'status': 'Active',
#   'address': 'THE VINES AT 49 HAWTHORDEN AVE',
#   'team': 'Conveyance'},
#  '6069W024': {'Sitno': '6069W024',
#   'StationId': 'IWSS',
#   'lat': -31.76726,
#   'lon': 116.02002,
#   'status': 'Active',
#   'address': 'TURNBERRY WAY H14 The Vines',
#   'team': 'Conveyance'},
#  '\r\n6069W032': {'Sitno': '\r\n6069W032',
#   'StationId': 'IWSS',
#   'lat': -31.76726,
#   'lon': 116.02002,
#   'status': 'Active',
#   'address': '50 Citrus Street Upper Swan',
#   'team': 'Conveyance'},
#  '6069W031': {'Sitno': '6069W031',
#   'StationId': 'IWSS',
#   'lat': -31.7692,
#   'lon': 116.02992,
#   'status': 'Active',
#   'address': '7 Orchard Street Upper Swan',
#   'team': 'Conveyance'},
#  '6038W005': {'Sitno': '6038W005',
#   'StationId': 'IWSS',
#   'lat': -31.62435,
#   'lon': 115.69595,
#   'status': 'Active',
#   'address': '56 Chesham Rise Alkimos',
#   'team': 'Conveyance'},
#  '6038W006': {'Sitno': '6038W006',
#   'StationId': 'IWSS',
#   'lat': -31.605,
#   'lon': 115.66324,
#   'status': 'Active',
#   'address': '79 Zodiac Drive Alkimos',
#   'team': 'Conveyance'},
#  '6038W007': {'Sitno': '6038W007',
#   'StationId': 'IWSS',
#   'lat': -31.59965,
#   'lon': 115.67805,
#   'status': 'Active',
#   'address': '52 Shipmaster Av Alkimos',
#   'team': 'Conveyance'},
#  '6031W030': {'Sitno': '6031W030',
#   'StationId': 'IWSS',
#   'lat': -31.70203,
#   'lon': 115.80447,
#   'status': 'Active',
#   'address': '27 Media Cr Banksia Grove',
#   'team': 'Conveyance'},
#  '6031W029': {'Sitno': '6031W029',
#   'StationId': 'IWSS',
#   'lat': -31.68871,
#   'lon': 115.80908,
#   'status': 'Active',
#   'address': '57 Boomerang Loop Banksia Grove',
#   'team': 'Conveyance'},
#  '6036W010': {'Sitno': '6036W010',
#   'StationId': 'IWSS',
#   'lat': -31.63173,
#   'lon': 115.7069,
#   'status': 'Active',
#   'address': 'BUTLER AT 247 LANDBEACH BVD',
#   'team': 'Conveyance'},
#  '6034W001': {'Sitno': '6034W001',
#   'StationId': 'IWSS',
#   'lat': -31.57686,
#   'lon': 115.6647,
#   'status': 'Active',
#   'address': '5 Revolution Ave Eglington',
#   'team': 'Conveyance'},
#  '6065W032': {'Sitno': '6065W032',
#   'StationId': 'IWSS',
#   'lat': -31.81158,
#   'lon': 115.85928,
#   'status': 'Active',
#   'address': '4 Meadowbank Way Landsdale',
#   'team': 'Conveyance'},
#  '6031W027': {'Sitno': '6031W027',
#   'StationId': 'IWSS',
#   'lat': -31.68004,
#   'lon': 115.78883,
#   'status': 'Active',
#   'address': ' 69 Mather Dr Neerabup',
#   'team': 'Conveyance'},
#  '6031W028': {'Sitno': '6031W028',
#   'StationId': 'IWSS',
#   'lat': -31.68199,
#   'lon': 115.7825,
#   'status': 'Active',
#   'address': '53 Avery St Neerabup',
#   'team': 'Conveyance'},
#  '6065W033': {'Sitno': '6065W033',
#   'StationId': 'IWSS',
#   'lat': -31.75573,
#   'lon': 115.81929,
#   'status': 'Active',
#   'address': '4 Aquantia Pl Wanneroo',
#   'team': 'Conveyance'},
#  '6209W002': {'Sitno': '6209W002',
#   'StationId': 'IWSS',
#   'lat': -32.56015,
#   'lon': 115.76413,
#   'status': 'Active',
#   'address': '22 Ronlyn Rd Furnissdale',
#   'team': 'Conveyance'},
#  '6210W045': {'Sitno': '6210W045',
#   'StationId': 'IWSS',
#   'lat': -32.5565,
#   'lon': 115.68567,
#   'status': 'Active',
#   'address': '31 Bookleaf lp Halls Head',
#   'team': 'Conveyance'},
#  '6176W002': {'Sitno': '6176W002',
#   'StationId': 'IWSS',
#   'lat': -32.4429,
#   'lon': 115.76983,
#   'status': 'Active',
#   'address': 'OPPOSITE 16 Navajo Rd Karnup',
#   'team': 'Conveyance'},
#  '6180W009': {'Sitno': '6180W009',
#   'StationId': 'IWSS',
#   'lat': -32.47095,
#   'lon': 115.77904,
#   'status': 'Active',
#   'address': '281 Lake Valley Drive Lakelands',
#   'team': 'Conveyance'},
#  '6210W198': {'Sitno': '6210W198',
#   'StationId': 'IWSS',
#   'lat': -32.47655,
#   'lon': 115.75373,
#   'status': 'Active',
#   'address': '9 Barringarra Rd Madora Bay',
#   'team': 'Conveyance'},
#  '6210W200': {'Sitno': '6210W200',
#   'StationId': 'IWSS',
#   'lat': -32.46649,
#   'lon': 115.75557,
#   'status': 'Active',
#   'address': '14 Pismo St Madora Bay',
#   'team': 'Conveyance'},
#  '6210W197': {'Sitno': '6210W197',
#   'StationId': 'IWSS',
#   'lat': -32.48774,
#   'lon': 115.76425,
#   'status': 'Active',
#   'address': '9 St Pierre Loop Meadow Spring',
#   'team': 'Conveyance'},
#  '6207W003': {'Sitno': '6207W003',
#   'StationId': 'IWSS',
#   'lat': -32.52033,
#   'lon': 115.96749,
#   'status': 'Active',
#   'address': '25 South St North Dandalup',
#   'team': 'Conveyance'},
#  '6208W060': {'Sitno': '6208W060',
#   'StationId': 'IWSS',
#   'lat': -32.5779,
#   'lon': 115.79738,
#   'status': 'Active',
#   'address': 'NORTH YUNDERUP AT 168 CULEENUP RD',
#   'team': 'Conveyance'},
#  '6208W055': {'Sitno': '6208W055',
#   'StationId': 'IWSS',
#   'lat': -32.60603,
#   'lon': 115.85845,
#   'status': 'Active',
#   'address': '29 Sunset Cir Pinjarra',
#   'team': 'Conveyance'},
#  '6175W008': {'Sitno': '6175W008',
#   'StationId': 'IWSS',
#   'lat': -32.43616,
#   'lon': 115.7616,
#   'status': 'Active',
#   'address': '40 Lookout Vista Singleton',
#   'team': 'Conveyance'},
#  '6208W056': {'Sitno': '6208W056',
#   'StationId': 'IWSS',
#   'lat': -32.58867,
#   'lon': 115.77561,
#   'status': 'Active',
#   'address': '22 Tanderra Pl South Yunderup',
#   'team': 'Conveyance'},
#  '6208W057': {'Sitno': '6208W057',
#   'StationId': 'IWSS',
#   'lat': -32.59365,
#   'lon': 115.81001,
#   'status': 'Active',
#   'address': '19 Pegus Mndr South Yunderup ',
#   'team': 'Conveyance'},
#  '6122W021': {'Sitno': '6122W021',
#   'StationId': 'IWSS',
#   'lat': -32.23537,
#   'lon': 115.991,
#   'status': 'Active',
#   'address': 'BYFORD AT 4 WOOMERA GRANGE',
#   'team': 'Conveyance'},
#  '6125W008': {'Sitno': '6125W008',
#   'StationId': 'IWSS',
#   'lat': -32.3741,
#   'lon': 115.9609,
#   'status': 'Active',
#   'address': 'SERPENTINE AT 2 BUSHEL RD ON WALKER RD',
#   'team': 'Conveyance'},
#  '6148W003': {'Sitno': '6148W003',
#   'StationId': 'IWSS',
#   'lat': -32.02223,
#   'lon': 115.89314,
#   'status': 'Active',
#   'address': 'SHELLEY AT 1 LINKWATER ST',
#   'team': 'Conveyance'},
#  '6112W047': {'Sitno': '6112W047',
#   'StationId': 'IWSS',
#   'lat': -32.1583,
#   'lon': 116.01532,
#   'status': 'Active',
#   'address': '21 John Street Armadale',
#   'team': 'Conveyance'},
#  '6112W050': {'Sitno': '6112W050',
#   'StationId': 'IWSS',
#   'lat': -32.13437,
#   'lon': 116.01657,
#   'status': 'Active',
#   'address': 'LATHWELL ST H33 Armadale',
#   'team': 'Conveyance'},
#  '6171W042': {'Sitno': '6171W042',
#   'StationId': 'IWSS',
#   'lat': -32.35389,
#   'lon': 115.80595,
#   'status': 'Active',
#   'address': 'Opp. 72 Ridge Bvd Baldivis Baldivis ',
#   'team': 'Conveyance'},
#  '6112W048': {'Sitno': '6112W048',
#   'StationId': 'IWSS',
#   'lat': -32.17356,
#   'lon': 116.00764,
#   'status': 'Active',
#   'address': '203 Wungong Rd Brookdale',
#   'team': 'Conveyance'},
#  '6122W017': {'Sitno': '6122W017',
#   'StationId': 'IWSS',
#   'lat': -32.23938,
#   'lon': 115.98117,
#   'status': 'Active',
#   'address': '19 Culham Vista Byford',
#   'team': 'Conveyance'},
#  '6122W016': {'Sitno': '6122W016',
#   'StationId': 'IWSS',
#   'lat': -32.22351,
#   'lon': 116.01163,
#   'status': 'Active',
#   'address': '15 Camembert St Byford',
#   'team': 'Conveyance'},
#  '6125W002': {'Sitno': '6125W002',
#   'StationId': 'IWSS',
#   'lat': -32.20968,
#   'lon': 115.98573,
#   'status': 'Active',
#   'address': 'BARJADDA ST H19 BYFORD',
#   'team': 'Conveyance'},
#  '6155W041': {'Sitno': '6155W041',
#   'StationId': 'IWSS',
#   'lat': -32.07874,
#   'lon': 115.9101,
#   'status': 'Active',
#   'address': '33 The Heights Canning Vale ',
#   'team': 'Conveyance'},
#  '6155W069': {'Sitno': '6155W069',
#   'StationId': 'IWSS',
#   'lat': -32.08175,
#   'lon': 115.9061,
#   'status': 'Active',
#   'address': 'CANNING VALE AT 7 RANGEVIEW PL',
#   'team': 'Conveyance'},
#  '6101W008': {'Sitno': '6101W008',
#   'StationId': 'IWSS',
#   'lat': -31.9911,
#   'lon': 115.89742,
#   'status': 'Active',
#   'address': 'EAST VICTORIA PARK AT 121 CANTERBURY TCE',
#   'team': 'Conveyance'},
#  '\r\n6112W058': {'Sitno': '\r\n6112W058',
#   'StationId': 'IWSS',
#   'lat': -32.11662,
#   'lon': 115.91809,
#   'status': 'Active',
#   'address': '12 MacDougal Way Harrisdale',
#   'team': 'Conveyance'},
#  '6056W037': {'Sitno': '6056W037',
#   'StationId': 'IWSS',
#   'lat': -31.92248,
#   'lon': 116.03175,
#   'status': 'Active',
#   'address': 'HELENA VALLEY AT 43 GREYSTONE TCE',
#   'team': 'Conveyance'},
#  '6112W051': {'Sitno': '6112W051',
#   'StationId': 'IWSS',
#   'lat': -32.1782,
#   'lon': 115.99253,
#   'status': 'Active',
#   'address': '18 Hilarion Elbow Hilbert',
#   'team': 'Conveyance'},
#  '6112W052': {'Sitno': '6112W052',
#   'StationId': 'IWSS',
#   'lat': -32.17826,
#   'lon': 115.96507,
#   'status': 'Active',
#   'address': '24 Oaklawn St Hilbert',
#   'team': 'Conveyance'},
#  '6123W004': {'Sitno': '6123W004',
#   'StationId': 'IWSS',
#   'lat': -32.28039,
#   'lon': 116.00043,
#   'status': 'Active',
#   'address': '25 Haywire Ave Mundijong',
#   'team': 'Conveyance'},
#  '6112W028': {'Sitno': '6112W028',
#   'StationId': 'IWSS',
#   'lat': -32.13877,
#   'lon': 115.92577,
#   'status': 'Active',
#   'address': 'RIVA ENT & BARCELONA  Piara Waters',
#   'team': 'Conveyance'},
#  '6125W006': {'Sitno': '6125W006',
#   'StationId': 'IWSS',
#   'lat': -32.37613,
#   'lon': 115.98288,
#   'status': 'Active',
#   'address': 'SERPENTINE AT 92 RANGEVIEW LOOP',
#   'team': 'Conveyance'},
#  '6125W007': {'Sitno': '6125W007',
#   'StationId': 'IWSS',
#   'lat': -32.36409,
#   'lon': 115.9774,
#   'status': 'Active',
#   'address': 'SERPENTINE AT 4 WELLARD ST',
#   'team': 'Conveyance'},
#  '6112W045': {'Sitno': '6112W045',
#   'StationId': 'IWSS',
#   'lat': -32.13169,
#   'lon': 115.98907,
#   'status': 'Active',
#   'address': '42 McCubbin Loop Seville Grove',
#   'team': 'Conveyance'},
#  '6110W051': {'Sitno': '6110W051',
#   'StationId': 'IWSS',
#   'lat': -32.10545,
#   'lon': 115.95802,
#   'status': 'Active',
#   'address': 'CLEARWATER DR H22 Southern River',
#   'team': 'Conveyance'},
#  '6108W020': {'Sitno': '6108W020',
#   'StationId': 'IWSS',
#   'lat': -32.08149,
#   'lon': 115.95092,
#   'status': 'Active',
#   'address': 'ROSEWOOD LANE H21 Thornlie',
#   'team': 'Conveyance'},
#  '6171W043': {'Sitno': '6171W043',
#   'StationId': 'IWSS',
#   'lat': -32.35416,
#   'lon': 115.8121,
#   'status': 'Active',
#   'address': 'BALDIVIS AT 23 KEMPEANA WAY',
#   'team': 'Conveyance'},
#  '6167W033': {'Sitno': '6167W033',
#   'StationId': 'IWSS',
#   'lat': -32.23755,
#   'lon': 115.87749,
#   'status': 'Active',
#   'address': 'CASUARINA ORTON RD OPP PRISON',
#   'team': 'Conveyance'},
#  '6167W034': {'Sitno': '6167W034',
#   'StationId': 'IWSS',
#   'lat': -32.23569,
#   'lon': 115.88244,
#   'status': 'Active',
#   'address': 'CASUARINA AT 4 TIANA COVE',
#   'team': 'Conveyance'},
#  '6167W035': {'Sitno': '6167W035',
#   'StationId': 'IWSS',
#   'lat': -32.23085,
#   'lon': 115.82776,
#   'status': 'Active',
#   'address': 'ORELIA AT 27 BERKLEY WAY',
#   'team': 'Conveyance'},
#  '6171W044': {'Sitno': '6171W044',
#   'StationId': 'IWSS',
#   'lat': -32.35901,
#   'lon': 115.79244,
#   'status': 'Active',
#   'address': 'BALDIVIS AT 25 GREYGUM RIDGE',
#   'team': 'Conveyance'},
#  '6164W074': {'Sitno': '6164W074',
#   'StationId': 'IWSS',
#   'lat': -32.17716,
#   'lon': 115.83693,
#   'status': 'Active',
#   'address': '40 Barfield Rd  Hammond Park',
#   'team': 'Conveyance'},
#  '6164W077': {'Sitno': '6164W077',
#   'StationId': 'IWSS',
#   'lat': -32.17716,
#   'lon': 115.83693,
#   'status': 'Active',
#   'address': '408 Wattleup Rd Hammond Park',
#   'team': 'Conveyance'},
#  '6164W026': {'Sitno': '6164W026',
#   'StationId': 'IWSS',
#   'lat': -32.09785,
#   'lon': 115.85601,
#   'status': 'Active',
#   'address': '18 Kooyonga Crs Jandakot',
#   'team': 'Conveyance'},
#  '6167W016': {'Sitno': '6167W016',
#   'StationId': 'IWSS',
#   'lat': -32.23202,
#   'lon': 115.78117,
#   'status': 'Active',
#   'address': 'KWINANA BEACH AT 1 YEATES RD',
#   'team': 'Conveyance'},
#  '6163W091': {'Sitno': '6163W091',
#   'StationId': 'IWSS',
#   'lat': -32.08323,
#   'lon': 115.7594,
#   'status': 'Active',
#   'address': '3 Darkan Ave North Coogee',
#   'team': 'Conveyance'},
#  '6164W075': {'Sitno': '6164W075',
#   'StationId': 'IWSS',
#   'lat': -32.13746,
#   'lon': 115.85064,
#   'status': 'Active',
#   'address': '34 Shala Way Success\r\n34 Marraboor Pl Success',
#   'team': 'Conveyance'},
#  '6164W076': {'Sitno': '6164W076',
#   'StationId': 'IWSS',
#   'lat': -32.11715,
#   'lon': 115.8729,
#   'status': 'Active',
#   'address': '10 Mercury Street Treeby',
#   'team': 'Conveyance'},
#  '6164W078': {'Sitno': '6164W078',
#   'StationId': 'IWSS',
#   'lat': -32.11972,
#   'lon': 115.88279,
#   'status': 'Active',
#   'address': '12 Mangrove Street Treeby',
#   'team': 'Conveyance'},
#  '6164W079': {'Sitno': '6164W079',
#   'StationId': 'IWSS',
#   'lat': -32.11992,
#   'lon': 115.87661,
#   'status': 'Active',
#   'address': '72 Sunstone Blvd Treeby',
#   'team': 'Conveyance'},
#  '6167W032': {'Sitno': '6167W032',
#   'StationId': 'IWSS',
#   'lat': -32.1938,
#   'lon': 115.86164,
#   'status': 'Active',
#   'address': '62 Honeywood Ave Wandi Wandi',
#   'team': 'Conveyance'},
#  '6167W027': {'Sitno': '6167W027',
#   'StationId': 'IWSS',
#   'lat': -32.20349,
#   'lon': 115.86196,
#   'status': 'Active',
#   'address': '39 Saltbush Street Wandi',
#   'team': 'Conveyance'},
#  '6170W007': {'Sitno': '6170W007',
#   'StationId': 'IWSS',
#   'lat': -32.25814,
#   'lon': 115.86323,
#   'status': 'Active',
#   'address': 'OPP 9 WOOLCOOT Wellard',
#   'team': 'Conveyance'},
#  '6170W005': {'Sitno': '6170W005',
#   'StationId': 'IWSS',
#   'lat': -32.27082,
#   'lon': 115.82957,
#   'status': 'Active',
#   'address': '5 Wheelwright Gdns Wellard',
#   'team': 'Conveyance'},
#  '6170W010': {'Sitno': '6170W010',
#   'StationId': 'IWSS',
#   'lat': -32.27153,
#   'lon': 115.82663,
#   'status': 'Inactive',
#   'address': '31 BRANTWOOD TURN  Wellard',
#   'team': 'Conveyance'},
#  '6164W025': {'Sitno': '6164W025',
#   'StationId': 'IWSS',
#   'lat': -32.11943,
#   'lon': 115.81421,
#   'status': 'fault',
#   'address': '12 The Summit Yangebup',
#   'team': 'Conveyance'},
#  '6142517': {'Sitno': '6142517',
#   'StationId': 'Level',
#   'lat': -32.14443,
#   'lon': 115.82909,
#   'status': 'Active',
#   'address': 'Thomsons lake - Thomsons Lake (6142517)',
#   'team': 'Conveyance'},
#  '6142520': {'Sitno': '6142520',
#   'StationId': 'Level',
#   'lat': -32.0913,
#   'lon': 115.82124,
#   'status': 'Active',
#   'address': 'Bibra Lake - Bibra Lake (6142520)',
#   'team': 'Conveyance'},
#  '6142522': {'Sitno': '6142522',
#   'StationId': 'Level',
#   'lat': -32.13775,
#   'lon': 115.83169,
#   'status': 'Active',
#   'address': 'Kogalup Lake - Kogalup Lake South (6142522)',
#   'team': 'Conveyance'},
#  '6142523': {'Sitno': '6142523',
#   'StationId': 'Level',
#   'lat': -32.12387,
#   'lon': 115.83158,
#   'status': 'Active',
#   'address': 'Lake Yangebup - Lake Yangebup (6142523)',
#   'team': 'Conveyance'},
#  '6142575': {'Sitno': '6142575',
#   'StationId': 'Level',
#   'lat': -32.13158,
#   'lon': 115.8316,
#   'status': 'Active',
#   'address': 'Kogalup Lake - Kogalup Lake North (6142575)',
#   'team': 'Conveyance'},
#  'D2001015': {'Sitno': 'D2001015',
#   'StationId': 'Level',
#   'lat': -32.06276,
#   'lon': 115.92916,
#   'status': 'Active',
#   'address': 'Hughes St BD - Magnet Rd CB',
#   'team': 'Conveyance'},
#  'D2001017': {'Sitno': 'D2001017',
#   'StationId': 'Level',
#   'lat': -31.88087,
#   'lon': 115.86129,
#   'status': 'Active',
#   'address': 'Bertram St BD - M105 (Gay St CB)',
#   'team': 'Conveyance'},
#  'D2001019': {'Sitno': 'D2001019',
#   'StationId': 'Level',
#   'lat': -31.91881,
#   'lon': 115.92214,
#   'status': 'Active',
#   'address': 'Bayswater MD - M101 (Inlet A018 Clavering Rd)',
#   'team': 'Conveyance'},
#  'D2001021': {'Sitno': 'D2001021',
#   'StationId': 'Level',
#   'lat': -31.89506,
#   'lon': 115.8888,
#   'status': 'Active',
#   'address': 'Peters Place Reserve, Light Street Morley ',
#   'team': 'Conveyance'},
#  'D2001023': {'Sitno': 'D2001023',
#   'StationId': 'Level',
#   'lat': -31.88485,
#   'lon': 116.03325,
#   'status': 'Active',
#   'address': 'Woodbridge Creek BD - M021 (Inlet B009/Farrall Rd)',
#   'team': 'Conveyance'},
#  'D2001025': {'Sitno': 'D2001025',
#   'StationId': 'Level',
#   'lat': -31.88602,
#   'lon': 116.04573,
#   'status': 'Active',
#   'address': 'Woodbridge Creek BD - M029 (Inlet E001/Morrison Rd CB)',
#   'team': 'Conveyance'},
#  'D2001027': {'Sitno': 'D2001027',
#   'StationId': 'Level',
#   'lat': -31.87633,
#   'lon': 116.00942,
#   'status': 'Active',
#   'address': 'Blackadder Creek MD - U/S of A023? (Gt Nth Hwy)  try A018?',
#   'team': 'Conveyance'},
#  'D2001029': {'Sitno': 'D2001029',
#   'StationId': 'Level',
#   'lat': -32.05898,
#   'lon': 115.81464,
#   'status': 'Active',
#   'address': 'Kardinya BD - M080 (Frederick Balwin Pk CB)',
#   'team': 'Conveyance'},
#  'D2001031': {'Sitno': 'D2001031',
#   'StationId': 'Level',
#   'lat': -32.05921,
#   'lon': 115.85186,
#   'status': 'Active',
#   'address': 'Bateman Road BD - M051 (Endeavour Ave CB)',
#   'team': 'Conveyance'},
#  'D2001033': {'Sitno': 'D2001033',
#   'StationId': 'Level',
#   'lat': -31.86172,
#   'lon': 115.81197,
#   'status': 'Active',
#   'address': 'Delawney BD - M016 (Cressall Rd CB)',
#   'team': 'Conveyance'},
#  'D2001035': {'Sitno': 'D2001035',
#   'StationId': 'Level',
#   'lat': -31.86263,
#   'lon': 115.80722,
#   'status': 'Active',
#   'address': 'Delawney BD - M017 (Whipple St CB/Inlet E018)',
#   'team': 'Conveyance'},
#  'D2001037': {'Sitno': 'D2001037',
#   'StationId': 'Level',
#   'lat': -31.86656,
#   'lon': 115.80574,
#   'status': 'Active',
#   'address': 'Delawney BD - M018 (Ledgar Rd CB)',
#   'team': 'Conveyance'},
#  'D2001039': {'Sitno': 'D2001039',
#   'StationId': 'Level',
#   'lat': -31.85565,
#   'lon': 115.80675,
#   'status': 'Active',
#   'address': 'Dutton Cr BD - M015 (Dutton Cr CB/Inlet F009)   ',
#   'team': 'Conveyance'},
#  'D2001041': {'Sitno': 'D2001041',
#   'StationId': 'Level',
#   'lat': -31.83397,
#   'lon': 115.78728,
#   'status': 'Active',
#   'address': 'Merrick Wy BD - M059 (Merrick Wy CB)',
#   'team': 'Conveyance'},
#  'D2001043': {'Sitno': 'D2001043',
#   'StationId': 'Level',
#   'lat': -31.90875,
#   'lon': 115.94019,
#   'status': 'Active',
#   'address': 'Chapman St MD - M125 (Railway Museum East CB)',
#   'team': 'Conveyance'},
#  'D2001045': {'Sitno': 'D2001045',
#   'StationId': 'Level',
#   'lat': -31.93309,
#   'lon': 115.85105,
#   'status': 'Active',
#   'address': 'Claisebrook MD - M011 (Smiths Lake CB)',
#   'team': 'Conveyance'},
#  'D2001047': {'Sitno': 'D2001047',
#   'StationId': 'Level',
#   'lat': -31.91038,
#   'lon': 115.84632,
#   'status': 'Active',
#   'address': 'Powell St MD - M012 (Dog Swamp CB)',
#   'team': 'Conveyance'},
#  'D2001049': {'Sitno': 'D2001049',
#   'StationId': 'Level',
#   'lat': -31.90553,
#   'lon': 115.84989,
#   'status': 'Active',
#   'address': 'Wellington Pde BD - M119 (Wellington Pde CB)',
#   'team': 'Conveyance'},
#  'D2001051': {'Sitno': 'D2001051',
#   'StationId': 'Level',
#   'lat': -31.90783,
#   'lon': 115.85939,
#   'status': 'Active',
#   'address': 'Wordsworth Ave BD - M120 (Yokine Res CB)',
#   'team': 'Conveyance'},
#  'D2001053': {'Sitno': 'D2001053',
#   'StationId': 'Level',
#   'lat': -31.9069,
#   'lon': 115.76871,
#   'status': 'Active',
#   'address': 'Cobb St BD - M107 (Cobb St CB)',
#   'team': 'Conveyance'},
#  'D2001055': {'Sitno': 'D2001055',
#   'StationId': 'Level',
#   'lat': -31.89971,
#   'lon': 115.7667,
#   'status': 'Active',
#   'address': 'Colin Rd MD - M108 (Colin Rd CB)',
#   'team': 'Conveyance'},
#  'D2001057': {'Sitno': 'D2001057',
#   'StationId': 'Level',
#   'lat': -31.89369,
#   'lon': 115.76351,
#   'status': 'Active',
#   'address': 'Joyce St BD - M066 (Joyce St CB)',
#   'team': 'Conveyance'},
#  'D2001059': {'Sitno': 'D2001059',
#   'StationId': 'Level',
#   'lat': -31.88932,
#   'lon': 115.76499,
#   'status': 'Active',
#   'address': 'Abbett Park BD - M109 (Abbett Pk CB)',
#   'team': 'Conveyance'},
#  'D2001061': {'Sitno': 'D2001061',
#   'StationId': 'Level',
#   'lat': -31.85756,
#   'lon': 115.92649,
#   'status': 'Active',
#   'address': 'Beechboro/Emu Swamp MD - M075 (Inlet A041/Bennett Springs Dr)',
#   'team': 'Conveyance'},
#  'D2001063': {'Sitno': 'D2001063',
#   'StationId': 'Level',
#   'lat': -31.86129,
#   'lon': 115.93173,
#   'status': 'Active',
#   'address': 'Emu Swamp MD - Hillwater Prom CB/Inlet A019',
#   'team': 'Conveyance'},
#  'D2001065': {'Sitno': 'D2001065',
#   'StationId': 'Level',
#   'lat': -32.30167,
#   'lon': 115.7174,
#   'status': 'Active',
#   'address': 'Forrester Rd MD - Forrester Rd CB',
#   'team': 'Conveyance'},
#  'D2001067': {'Sitno': 'D2001067',
#   'StationId': 'Level',
#   'lat': -31.90321,
#   'lon': 115.80066,
#   'status': 'Active',
#   'address': 'Osborne Park BD - Inlet H011 (Scarborough Beach Rd)',
#   'team': 'Conveyance'},
#  'D2001069': {'Sitno': 'D2001069',
#   'StationId': 'Level',
#   'lat': -31.98964,
#   'lon': 115.94404,
#   'status': 'Active',
#   'address': 'Mills St MD - M033 (Pilbara St CB)',
#   'team': 'Conveyance'},
#  'D2001071': {'Sitno': 'D2001071',
#   'StationId': 'Level',
#   'lat': -32.00132,
#   'lon': 115.93388,
#   'status': 'Active',
#   'address': 'Mills St MD - M034 (Inlet A027 Mills St/Meuse Wy)',
#   'team': 'Conveyance'},
#  'D2001073': {'Sitno': 'D2001073',
#   'StationId': 'Level',
#   'lat': -31.99607,
#   'lon': 115.92219,
#   'status': 'Active',
#   'address': 'Welshpool BD - M036 (Charles St CB)',
#   'team': 'Conveyance'},
#  'D2001075': {'Sitno': 'D2001075',
#   'StationId': 'Level',
#   'lat': -31.99608,
#   'lon': 115.9179,
#   'status': 'Active',
#   'address': 'Welshpool BD - M053 (Ellam St East CB)',
#   'team': 'Conveyance'},
#  'D2001077': {'Sitno': 'D2001077',
#   'StationId': 'Level',
#   'lat': -31.98752,
#   'lon': 115.93773,
#   'status': 'Active',
#   'address': 'Abernethy Rd BD - M067 (Division St CB)',
#   'team': 'Conveyance'},
#  'D2001079': {'Sitno': 'D2001079',
#   'StationId': 'Level',
#   'lat': -31.99188,
#   'lon': 115.91708,
#   'status': 'Active',
#   'address': 'Welshpool BD - M069 (Forward St CB)',
#   'team': 'Conveyance'},
#  'D2001081': {'Sitno': 'D2001081',
#   'StationId': 'Level',
#   'lat': -32.00481,
#   'lon': 115.92576,
#   'status': 'Active',
#   'address': 'Welshpool BD - M078 (Alexandra Pl CB)',
#   'team': 'Conveyance'},
#  'D2001083': {'Sitno': 'D2001083',
#   'StationId': 'Level',
#   'lat': -32.0029,
#   'lon': 115.93256,
#   'status': 'Active',
#   'address': 'Mills St MD - M035 (MH A019/Sevenoaks St) - was GIS041 changed location',
#   'team': 'Conveyance'},
#  'D2001085': {'Sitno': 'D2001085',
#   'StationId': 'Level',
#   'lat': -32.00083,
#   'lon': 115.93383,
#   'status': 'Active',
#   'address': 'Kalgan Rd BD - M081 (Inlet E003/10 Tilli Pl)',
#   'team': 'Conveyance'},
#  'D2001087': {'Sitno': 'D2001087',
#   'StationId': 'Level',
#   'lat': -32.14941,
#   'lon': 115.98855,
#   'status': 'Active',
#   'address': 'Neerigen Brook Nth MD - Inlet E023 (Next to 98 Girrawheen St)',
#   'team': 'Conveyance'},
#  'D2001089': {'Sitno': 'D2001089',
#   'StationId': 'Level',
#   'lat': -31.97339,
#   'lon': 115.98864,
#   'status': 'Inactive',
#   'address': 'Crumpet Creek - M077 (521 Old Dundas Rd)',
#   'team': 'Conveyance'},
#  'D2001091': {'Sitno': 'D2001091',
#   'StationId': 'Level',
#   'lat': -32.12261,
#   'lon': 115.99777,
#   'status': 'fault',
#   'address': 'Second Rd MD - Kuhl Park CB (Inlet A016)',
#   'team': 'Conveyance'},
#  'D2001093': {'Sitno': 'D2001093',
#   'StationId': 'Level',
#   'lat': -31.98384,
#   'lon': 115.92538,
#   'status': 'Active',
#   'address': 'Star St BD - M061 (Star St CB) ',
#   'team': 'Conveyance'},
#  'D2001095': {'Sitno': 'D2001095',
#   'StationId': 'Level',
#   'lat': -31.96208,
#   'lon': 115.93505,
#   'status': 'Active',
#   'address': 'Cloverdale BD - M079 (Faulkner Pk Sth CB)',
#   'team': 'Conveyance'},
#  'D2001097': {'Sitno': 'D2001097',
#   'StationId': 'Level',
#   'lat': -31.96504,
#   'lon': 115.81424,
#   'status': 'Active',
#   'address': 'Aberdare Rd BD - M004 (Aberdare Rd CB)',
#   'team': 'Conveyance'},
#  'D2001099': {'Sitno': 'D2001099',
#   'StationId': 'Level',
#   'lat': -31.95261,
#   'lon': 115.807,
#   'status': 'Active',
#   'address': 'Subiaco MD - M006 (Claypan CB/Inlet A021)',
#   'team': 'Conveyance'},
#  'D2001101': {'Sitno': 'D2001101',
#   'StationId': 'Level',
#   'lat': -31.98669,
#   'lon': 115.91929,
#   'status': 'Active',
#   'address': 'Victoria Park MD - Jupiter St CB',
#   'team': 'Conveyance'},
#  'D2001103': {'Sitno': 'D2001103',
#   'StationId': 'Level',
#   'lat': -31.98579,
#   'lon': 115.91383,
#   'status': 'Active',
#   'address': 'Victoria Park MD - Somerset St CB',
#   'team': 'Conveyance'},
#  'D2001105': {'Sitno': 'D2001105',
#   'StationId': 'Level',
#   'lat': -31.94447,
#   'lon': 115.81034,
#   'status': 'Active',
#   'address': 'Wembley MD - M013 (Mabel Talbot CB)',
#   'team': 'Conveyance'},
#  'D2001107': {'Sitno': 'D2001107',
#   'StationId': 'Level',
#   'lat': -32.10817,
#   'lon': 116.00791,
#   'status': 'Active',
#   'address': 'Westfield Park MD - M068 (Hemmingway Dr South CB)',
#   'team': 'Conveyance'},
#  'D2001109': {'Sitno': 'D2001109',
#   'StationId': 'Level',
#   'lat': -32.01615,
#   'lon': 115.93343,
#   'status': 'Active',
#   'address': 'Wharf Street MD - Wharf St CB',
#   'team': 'Conveyance'},
#  'D2001111': {'Sitno': 'D2001111',
#   'StationId': 'Level',
#   'lat': -32.14034,
#   'lon': 115.99799,
#   'status': 'Active',
#   'address': 'Williams Rd MD - Inlet A026 (Braemore St/Toorak Rd)',
#   'team': 'Conveyance'},
#  'D2001113': {'Sitno': 'D2001113',
#   'StationId': 'Level',
#   'lat': -31.8594,
#   'lon': 115.90332,
#   'status': 'Active',
#   'address': 'Malaga Dr BD - Cogla St CB',
#   'team': 'Conveyance'},
#  'D2001115': {'Sitno': 'D2001115',
#   'StationId': 'Level',
#   'lat': -31.99466,
#   'lon': 115.9645,
#   'status': 'Active',
#   'address': 'Black Creek BD - Banksia Rd CB',
#   'team': 'Conveyance'},
#  'D2001117': {'Sitno': 'D2001117',
#   'StationId': 'Level',
#   'lat': -31.99402,
#   'lon': 115.95026,
#   'status': 'Active',
#   'address': 'Treasure Rd BD - Treasure Rd CB',
#   'team': 'Conveyance'},
#  'D2001119': {'Sitno': 'D2001119',
#   'StationId': 'Level',
#   'lat': -32.00842,
#   'lon': 115.97375,
#   'status': 'Active',
#   'address': 'Woodlupine Brook BD - William St Sth CB (Inlet X017)',
#   'team': 'Conveyance'},
#  'D2001121': {'Sitno': 'D2001121',
#   'StationId': 'Level',
#   'lat': -31.98515,
#   'lon': 116.01731,
#   'status': 'Active',
#   'address': 'Woodlupine Brook BD - Hale Rd Culvert (Inlet D070)',
#   'team': 'Conveyance'},
#  'D2001123': {'Sitno': 'D2001123',
#   'StationId': 'Level',
#   'lat': -32.02801,
#   'lon': 115.96107,
#   'status': 'Active',
#   'address': 'Yule Brook MD - M038 (Inlet A013/Railway Pde)',
#   'team': 'Conveyance'},
#  'D2001125': {'Sitno': 'D2001125',
#   'StationId': 'Level',
#   'lat': -32.03256,
#   'lon': 115.95882,
#   'status': 'Active',
#   'address': 'Yule Brook MD - M041 (32 Ladywell St)',
#   'team': 'Conveyance'},
#  'D2001127': {'Sitno': 'D2001127',
#   'StationId': 'Level',
#   'lat': -31.99056,
#   'lon': 115.99747,
#   'status': 'Active',
#   'address': 'Woodlupine Brook BD - M049 (Inlet D042/Cypress Rd)',
#   'team': 'Conveyance'},
#  'D2001162': {'Sitno': 'D2001162',
#   'StationId': 'Level',
#   'lat': -32.05637,
#   'lon': 115.74556,
#   'status': 'Active',
#   'address': 'Essex St MD - MH A010 (Packenham St/Nairn St)',
#   'team': 'Conveyance'},
#  'D2001164': {'Sitno': 'D2001164',
#   'StationId': 'Level',
#   'lat': -32.05393,
#   'lon': 115.75175,
#   'status': 'Active',
#   'address': 'Essex St MD - MH A018 (Holdsworth St/Parry St)',
#   'team': 'Conveyance'},
#  'D2001166': {'Sitno': 'D2001166',
#   'StationId': 'Level',
#   'lat': -32.05989,
#   'lon': 115.75017,
#   'status': 'Inactive',
#   'address': 'Howard St MD - MH A003 (14 Howard St)',
#   'team': 'Conveyance'},
#  'D2001184': {'Sitno': 'D2001184',
#   'StationId': 'Level',
#   'lat': -31.90019,
#   'lon': 115.76684,
#   'status': 'fault',
#   'address': 'Cobb St BD - MH E002 (12 Colin Rd)',
#   'team': 'Conveyance'},
#  'D2001186': {'Sitno': 'D2001186',
#   'StationId': 'Level',
#   'lat': -31.98647,
#   'lon': 115.78296,
#   'status': 'Active',
#   'address': 'Bayview Tce MD - MH A006 (12 Princess Rd)',
#   'team': 'Conveyance'},
#  'D2001188': {'Sitno': 'D2001188',
#   'StationId': 'Level',
#   'lat': -31.95211,
#   'lon': 115.8641,
#   'status': 'Active',
#   'address': 'Wellington St BD - MH C006 (M117A/Pier St)',
#   'team': 'Conveyance'},
#  'D2001190': {'Sitno': 'D2001190',
#   'StationId': 'Level',
#   'lat': -31.92617,
#   'lon': 115.8835,
#   'status': 'Active',
#   'address': 'Maylands-Inglewood MD - MH A020 (Central Ave/John St)',
#   'team': 'Conveyance'},
#  'D2001192': {'Sitno': 'D2001192',
#   'StationId': 'Level',
#   'lat': -31.94884,
#   'lon': 115.85374,
#   'status': 'Active',
#   'address': 'Milligan St BD - MH F005 ',
#   'team': 'Conveyance'},
#  'D2001212': {'Sitno': 'D2001212',
#   'StationId': 'Level',
#   'lat': -32.03797,
#   'lon': 115.91745,
#   'status': 'Active',
#   'address': 'Bannister Creek MD - Inlet A003 (Bursaria Cr/Hybanthus Rd)',
#   'team': 'Conveyance'},
#  'D2001215': {'Sitno': 'D2001215',
#   'StationId': 'Level',
#   'lat': -31.89692,
#   'lon': 115.76482,
#   'status': 'Active',
#   'address': 'Deanmore SQ BD - M126 (Deanmore Sq CB/Outlet D005)',
#   'team': 'Conveyance'},
#  'D2001217': {'Sitno': 'D2001217',
#   'StationId': 'Level',
#   'lat': -31.94459,
#   'lon': 115.93431,
#   'status': 'Active',
#   'address': 'Durban St BD - Inlet C007 (21 Durban St)',
#   'team': 'Conveyance'},
#  'D2001218': {'Sitno': 'D2001218',
#   'StationId': 'Level',
#   'lat': -32.05646,
#   'lon': 115.99667,
#   'status': 'Active',
#   'address': 'Helm St MD - Inlet A009 (31 Helm St)',
#   'team': 'Conveyance'},
#  'D2001221': {'Sitno': 'D2001221',
#   'StationId': 'Level',
#   'lat': -31.92863,
#   'lon': 115.80523,
#   'status': 'Active',
#   'address': 'Herdsman Inner Ring Drain - Herdsman Wildlife Centre',
#   'team': 'Conveyance'},
#  'D2001222': {'Sitno': 'D2001222',
#   'StationId': 'Level',
#   'lat': -32.01756,
#   'lon': 115.91929,
#   'status': 'Active',
#   'address': 'Mills St MD - MH A002 (45 Fern Rd)',
#   'team': 'Conveyance'},
#  'D2001227': {'Sitno': 'D2001227',
#   'StationId': 'Level',
#   'lat': -32.15535,
#   'lon': 115.99919,
#   'status': 'Active',
#   'address': 'Neerigen Brook Sth MD - Inlet B036 (31 Dawson St)',
#   'team': 'Conveyance'},
#  'D2001229': {'Sitno': 'D2001229',
#   'StationId': 'Level',
#   'lat': -31.89475,
#   'lon': 115.81192,
#   'status': 'Active',
#   'address': 'Osborne Park BD - Inlet H017 (51 Telford Cres)',
#   'team': 'Conveyance'},
#  'D2001230': {'Sitno': 'D2001230',
#   'StationId': 'Level',
#   'lat': -31.88617,
#   'lon': 116.04656,
#   'status': 'Active',
#   'address': 'Rhine Park BD - Inlet F002 (Morrison Rd/Marboro Rd)',
#   'team': 'Conveyance'},
#  'D2001232': {'Sitno': 'D2001232',
#   'StationId': 'Level',
#   'lat': -31.95546,
#   'lon': 115.92256,
#   'status': 'Active',
#   'address': 'South Belmont MD - Inlet A014 (59 Newlyn St)',
#   'team': 'Conveyance'},
#  'D2001234': {'Sitno': 'D2001234',
#   'StationId': 'Level',
#   'lat': -31.88919,
#   'lon': 116.04902,
#   'status': 'Active',
#   'address': 'Watton Park BD - Watton Park North CB (E005) M027',
#   'team': 'Conveyance'},
#  'D2001236': {'Sitno': 'D2001236',
#   'StationId': 'Level',
#   'lat': -31.87016,
#   'lon': 115.89621,
#   'status': 'Active',
#   'address': 'Widgee Road BD - Outlet B065 (58 Ivory St)',
#   'team': 'Conveyance'},
#  'D2001239': {'Sitno': 'D2001239',
#   'StationId': 'Level',
#   'lat': -31.86019,
#   'lon': 115.94049,
#   'status': 'Active',
#   'address': 'Local Authority  - Plume Gdns CB (LA) (outlet side)',
#   'team': 'Conveyance'},
#  'D2001247': {'Sitno': 'D2001247',
#   'StationId': 'Level',
#   'lat': -32.06018,
#   'lon': 115.93067,
#   'status': 'Active',
#   'address': 'Hughes St BD - M043 (MH B024)',
#   'team': 'Conveyance'},
#  'D2001249': {'Sitno': 'D2001249',
#   'StationId': 'Level',
#   'lat': -31.94848,
#   'lon': 115.85084,
#   'status': 'Active',
#   'address': 'Fitzgerald St BD - MH X003 (Perth Arena)',
#   'team': 'Conveyance'},
#  'D2001251': {'Sitno': 'D2001251',
#   'StationId': 'Level',
#   'lat': -31.93688,
#   'lon': 115.8732,
#   'status': 'Inactive',
#   'address': 'Mount Lawley MD - MH A016 (23 Barlee St)',
#   'team': 'Conveyance'},
#  'D2001255': {'Sitno': 'D2001255',
#   'StationId': 'Level',
#   'lat': -31.94791,
#   'lon': 115.83098,
#   'status': 'fault',
#   'address': 'Subiaco MD - MH A043 (142 Churchill Av)',
#   'team': 'Conveyance'},
#  'D2001259': {'Sitno': 'D2001259',
#   'StationId': 'Level',
#   'lat': -32.05806,
#   'lon': 115.74605,
#   'status': 'Active',
#   'address': 'Essex St MD - MH A004 (The Esplanade Park)',
#   'team': 'Conveyance'},
#  'D2001261': {'Sitno': 'D2001261',
#   'StationId': 'Level',
#   'lat': -31.90007,
#   'lon': 115.80122,
#   'status': 'Active',
#   'address': 'Osborne Park BD - Node OSH11BLA1 (In Oswald St)',
#   'team': 'Conveyance'},
#  'D2001263': {'Sitno': 'D2001263',
#   'StationId': 'Level',
#   'lat': -31.86415,
#   'lon': 115.90436,
#   'status': 'Active',
#   'address': 'Malaga Dr BD - MH F012 (8 Meka St)',
#   'team': 'Conveyance'},
#  'D2001265': {'Sitno': 'D2001265',
#   'StationId': 'Level',
#   'lat': -32.02354,
#   'lon': 115.94996,
#   'status': 'Active',
#   'address': 'Lacey St MD - Bickley Rd CB (near outlet side)',
#   'team': 'Conveyance'},
#  'D2001267': {'Sitno': 'D2001267',
#   'StationId': 'Level',
#   'lat': -32.06774,
#   'lon': 115.75322,
#   'status': 'Active',
#   'address': 'Lefroy Rd MD  - MH X003 (15 Little Lefroy Rd)',
#   'team': 'Conveyance'},
#  'D2001269': {'Sitno': 'D2001269',
#   'StationId': 'Level',
#   'lat': -31.91036,
#   'lon': 115.8219,
#   'status': 'Active',
#   'address': 'Balgay BD - M064 (Outlet G039/Sangiorgio Ct)',
#   'team': 'Conveyance'},
#  'D2001271': {'Sitno': 'D2001271',
#   'StationId': 'Level',
#   'lat': -32.05204,
#   'lon': 115.75095,
#   'status': 'Active',
#   'address': 'Essex St MD - MH A023 (Parry St/Ellen St)',
#   'team': 'Conveyance'},
#  'D2001273': {'Sitno': 'D2001273',
#   'StationId': 'Level',
#   'lat': -32.05499,
#   'lon': 115.7421,
#   'status': 'Active',
#   'address': 'Cliff St MD - MH A005 (Cliff St/Phiillimore St)',
#   'team': 'Conveyance'},
#  'D2001275': {'Sitno': 'D2001275',
#   'StationId': 'Level',
#   'lat': -31.93946,
#   'lon': 115.86453,
#   'status': 'Active',
#   'address': 'Hyde Park BD - MH H006 (William St/Lincoln St)',
#   'team': 'Conveyance'},
#  'D2001277': {'Sitno': 'D2001277',
#   'StationId': 'Level',
#   'lat': -31.9852,
#   'lon': 115.78144,
#   'status': 'Active',
#   'address': 'Bay View Tce MD - MH A011 (Bayview Tce/Park Lane)',
#   'team': 'Conveyance'},
#  'D2001279': {'Sitno': 'D2001279',
#   'StationId': 'Level',
#   'lat': -31.98533,
#   'lon': 115.77513,
#   'status': 'Active',
#   'address': 'Bay View Tce MD - MH A019 (356 Stirling Hwy)',
#   'team': 'Conveyance'},
#  'D2001281': {'Sitno': 'D2001281',
#   'StationId': 'Level',
#   'lat': -31.94564,
#   'lon': 115.92935,
#   'status': 'Active',
#   'address': 'Hubert St BD - MH B004 (Daly St/KatoombaPl)',
#   'team': 'Conveyance'},
#  'D2001283': {'Sitno': 'D2001283',
#   'StationId': 'Level',
#   'lat': -31.9236,
#   'lon': 115.91737,
#   'status': 'Active',
#   'address': 'King William St BD - M071 (MH B013/90 King William St)',
#   'team': 'Conveyance'},
#  'D2001285': {'Sitno': 'D2001285',
#   'StationId': 'Level',
#   'lat': -31.90224,
#   'lon': 115.90147,
#   'status': 'Active',
#   'address': 'Browns Lake East BD - MH D012 (150/152 Russell St)',
#   'team': 'Conveyance'},
#  'D2001287': {'Sitno': 'D2001287',
#   'StationId': 'Level',
#   'lat': -31.92226,
#   'lon': 115.9158,
#   'status': 'Active',
#   'address': 'King William St BD - M072 (MH B016/60 King William St)',
#   'team': 'Conveyance'},
#  'D2001289': {'Sitno': 'D2001289',
#   'StationId': 'Level',
#   'lat': -31.89999,
#   'lon': 115.81851,
#   'status': 'Active',
#   'address': 'Hutton St BD - Inlet J004 (Mitchell Fwy)',
#   'team': 'Conveyance'},
#  'D2001291': {'Sitno': 'D2001291',
#   'StationId': 'Level',
#   'lat': -31.90907,
#   'lon': 115.79964,
#   'status': 'Active',
#   'address': 'Osborne Park BD - Inlet H008 ((Pearson St)',
#   'team': 'Conveyance'},
#  'D2001293': {'Sitno': 'D2001293',
#   'StationId': 'Level',
#   'lat': -31.90057,
#   'lon': 115.80263,
#   'status': 'Active',
#   'address': 'Osborne Park BD - Node OSH11B (near Oswald St)',
#   'team': 'Conveyance'},
#  'D2001295': {'Sitno': 'D2001295',
#   'StationId': 'Level',
#   'lat': -32.01558,
#   'lon': 115.95756,
#   'status': 'Active',
#   'address': 'Lacey St MD - Lacey St CB (near outlet side)',
#   'team': 'Conveyance'},
#  'D2001297': {'Sitno': 'D2001297',
#   'StationId': 'Level',
#   'lat': -31.87747,
#   'lon': 115.8297,
#   'status': 'Inactive',
#   'address': 'Beryl St BD - MH C013 (Beryl St/Campion Ave)',
#   'team': 'Conveyance'},
#  'D2001299': {'Sitno': 'D2001299',
#   'StationId': 'Level',
#   'lat': -32.05159,
#   'lon': 115.75196,
#   'status': 'fault',
#   'address': 'Essex St MD - MH A027 (29 Ellen St)',
#   'team': 'Conveyance'},
#  'D2001301': {'Sitno': 'D2001301',
#   'StationId': 'Level',
#   'lat': -31.95055,
#   'lon': 115.9299,
#   'status': 'Active',
#   'address': 'Hubert St BD - MH B019 (5 Fairbrother St)',
#   'team': 'Conveyance'},
#  'D2001303': {'Sitno': 'D2001303',
#   'StationId': 'Level',
#   'lat': -31.92325,
#   'lon': 115.84846,
#   'status': 'Active',
#   'address': 'Claisebrook MD - M008 (MH A055/35 Eton St) ',
#   'team': 'Conveyance'},
#  'D2001305': {'Sitno': 'D2001305',
#   'StationId': 'Level',
#   'lat': -31.94351,
#   'lon': 115.85956,
#   'status': 'Active',
#   'address': 'Claisebrook MD - MH A019 (Stuart St/Lake St)',
#   'team': 'Conveyance'},
#  'D2001307': {'Sitno': 'D2001307',
#   'StationId': 'Level',
#   'lat': -31.94794,
#   'lon': 115.8232,
#   'status': 'Active',
#   'address': 'Subiaco MD - M007 (MH A037-Rowland St/Forrest Wlk)',
#   'team': 'Conveyance'},
#  'D2001309': {'Sitno': 'D2001309',
#   'StationId': 'Level',
#   'lat': -31.94794,
#   'lon': 115.82761,
#   'status': 'Active',
#   'address': 'Subiaco MD - MH A040 (245 Churchill Ave)',
#   'team': 'Conveyance'},
#  'D2001311': {'Sitno': 'D2001311',
#   'StationId': 'Level',
#   'lat': -31.95091,
#   'lon': 115.83138,
#   'status': 'Active',
#   'address': 'Kings Park BD - MH J005 (44 Bedford St)',
#   'team': 'Conveyance'},
#  'D2001313': {'Sitno': 'D2001313',
#   'StationId': 'Level',
#   'lat': -31.86536,
#   'lon': 115.90445,
#   'status': 'Active',
#   'address': 'Malaga Dr BD - Glyde Ct CB',
#   'team': 'Conveyance'},
#  'D2001315': {'Sitno': 'D2001315',
#   'StationId': 'Level',
#   'lat': -31.93592,
#   'lon': 115.87946,
#   'status': 'Active',
#   'address': 'Railway Parade BD - MH B005 (Railway Pde/Almondbury Rd)',
#   'team': 'Conveyance'},
#  'D2001317': {'Sitno': 'D2001317',
#   'StationId': 'Level',
#   'lat': -31.93155,
#   'lon': 115.89339,
#   'status': 'Active',
#   'address': 'Seventh Ave BD - MH D003 (39 Seventh Ave)',
#   'team': 'Conveyance'},
#  'D2001319': {'Sitno': 'D2001319',
#   'StationId': 'Level',
#   'lat': -32.12943,
#   'lon': 115.77679,
#   'status': 'Active',
#   'address': 'Packham BD - Causeway CB (Fawcett Rd)',
#   'team': 'Conveyance'},
#  'D2001321': {'Sitno': 'D2001321',
#   'StationId': 'Level',
#   'lat': -32.12008,
#   'lon': 115.77917,
#   'status': 'Active',
#   'address': 'Packham BD - Market Garden Swamp (Troode St)',
#   'team': 'Conveyance'},
#  'D2001323': {'Sitno': 'D2001323',
#   'StationId': 'Level',
#   'lat': -32.29339,
#   'lon': 115.76698,
#   'status': 'Active',
#   'address': 'Elanora Dr BD - Cuthbertson Reserve Lake (Elanora Dr)',
#   'team': 'Conveyance'},
#  'D2001325': {'Sitno': 'D2001325',
#   'StationId': 'Level',
#   'lat': -32.1378,
#   'lon': 116.01477,
#   'status': 'Active',
#   'address': 'Rundle St MD - MH A040',
#   'team': 'Conveyance'},
#  'D2001327': {'Sitno': 'D2001327',
#   'StationId': 'Level',
#   'lat': -32.11809,
#   'lon': 116.01172,
#   'status': 'Active',
#   'address': 'Denny Av BD - B015(adjacent to Kelmscott Baptist Church)',
#   'team': 'Conveyance'},
#  'D2001333': {'Sitno': 'D2001333',
#   'StationId': 'Level',
#   'lat': -32.06368,
#   'lon': 115.75246,
#   'status': 'Active',
#   'address': 'South St MD - A004 (South St/South Tce)',
#   'team': 'Conveyance'},
#  'D2001336': {'Sitno': 'D2001336',
#   'StationId': 'Level',
#   'lat': -31.96117,
#   'lon': 115.87054,
#   'status': 'Active',
#   'address': 'Bennett St MD - A004 (Bennett St/Terrace Rd)',
#   'team': 'Conveyance'},
#  'D2001473': {'Sitno': 'D2001473',
#   'StationId': 'Level',
#   'lat': -31.94789,
#   'lon': 115.82753,
#   'status': 'Active',
#   'address': 'Subiaco MD - X006 (Churchill Ave)',
#   'team': 'Conveyance'},
#  'D2001855': {'Sitno': 'D2001855',
#   'StationId': 'Level',
#   'lat': -31.97676,
#   'lon': 115.81171,
#   'status': 'Active',
#   'address': 'Crawley BD- C007 (Clifton St Nedlands)',
#   'team': 'Conveyance'}}

# %%
# # Convert the dictionary to a DataFrame
# result_df = pd.DataFrame.from_dict(all_stations, orient='index')
# result_df
# # Save the DataFrame to a JSON file
# result_df.to_json('../Map/static/data/all_stations.json', orient='index', indent=2)

# %%
import json
# Convert dictionary to JSON string
json_data = json.dumps(all_stations, indent=2)

# Define the JavaScript variable assignment
js_content = f"var alldata = {json_data};"

# Write the JavaScript content to a file
with open('../Map/static/data/data.js', 'w') as js_file:
    js_file.write(js_content)
