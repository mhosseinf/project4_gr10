# %%
import pandas as pd
import requests
from pandas import json_normalize
from api_key import api_key

# %%
# Set the API base URL
url = "https://api.dpird.wa.gov.au/v2/weather/stations??offset=0&limit=225&group=all"
# Headers with API key
headers = {
    "api_key": api_key
}

# %%
# Parse the JSON and retrieve data
response = requests.get(url,headers=headers)
all_stations_data = response.json()

# %%
#convert the data to a DataFrame using pandas
weather_stations = all_stations_data['collection']
df = pd.DataFrame(weather_stations)

# Flatten nested 'capabilities'columns
df = pd.concat([df.drop(['capabilities'], axis=1), json_normalize(df['capabilities'])], axis=1)

# Drop rows with NA values in specific columns
columns_to_clean = ['stationCode', 'stationName', 'latitude', 'longitude']
df_cleaned = df.dropna(subset=columns_to_clean)

df
# Out:
#     stationCode  stationName   latitude   longitude  altitude  \
# 0         AN001    Allanooka -29.063612  114.997161     131.0
# 1         AM001       Amelup -34.270827  118.268523     200.0
# 2         SH002      Babakin -32.125480  118.004060     313.0
# 3            BA  Badgingarra -30.338049  115.539491     284.0
# 4         BP001     Balingup -33.796200  116.063980     227.0
# ..          ...          ...        ...         ...       ...
# 220       MA003       Yanmah -34.225653  116.017767     295.0
# 221          YS      Yilgarn -31.915622  119.256055     468.0
# 222       YE001    York East -31.835878  116.921077     229.0
# 223       YU001         Yuna -28.337630  114.989800     329.0
# 224       YU002      Yuna NE -28.200324  115.261614     267.0
#
#                                                  owner ownerCode   startDate  \
# 0    WA Department of Primary Industries and Region...     DPIRD  2012-06-19
# 1    WA Department of Primary Industries and Region...     DPIRD  2019-10-09
# 2    WA Department of Primary Industries and Region...     DPIRD  2016-06-22
# 3    WA Department of Primary Industries and Region...     DPIRD  2008-11-19
# 4    WA Department of Primary Industries and Region...     DPIRD  2014-10-24
# ..                                                 ...       ...         ...
# 220  WA Department of Primary Industries and Region...     DPIRD  2012-12-20
# 221  WA Department of Primary Industries and Region...     DPIRD  2008-11-01
# 222  WA Department of Primary Industries and Region...     DPIRD  2013-11-08
# 223  WA Department of Primary Industries and Region...     DPIRD  2012-06-21
# 224  WA Department of Primary Industries and Region...     DPIRD  2016-03-24
#
#     endDate  probeHeight  ...  wind2  wind3 apparentTemperature  etoShort  \
# 0      None         1.25  ...  False  False                True      True
# 1      None         1.25  ...  False  False                True      True
# 2      None         1.25  ...  False  False                True      True
# 3      None         1.25  ...  False  False                True      True
# 4      None         1.25  ...  False  False                True      True
# ..      ...          ...  ...    ...    ...                 ...       ...
# 220    None         1.25  ...  False  False                True      True
# 221    None         1.25  ...  False  False                True      True
# 222    None         1.25  ...  False  False                True      True
# 223    None         1.25  ...  False  False                True      True
# 224    None         1.25  ...  False  False                True      True
#
#     etoTall frostCondition heatCondition windErosionCondition  richardsonUnit  \
# 0      True           True          True                 True            True
# 1      True           True          True                 True            True
# 2      True           True          True                 True            True
# 3      True           True          True                 True            True
# 4      True           True          True                 True            True
# ..      ...            ...           ...                  ...             ...
# 220    True           True          True                 True            True
# 221    True           True          True                 True            True
# 222    True           True          True                 True            True
# 223    True           True          True                 True            True
# 224    True           True          True                 True            True
#
#      chillHour
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ..         ...
# 220       True
# 221       True
# 222       True
# 223       True
# 224       True
#
# [225 rows x 40 columns]

# %%
# Assuming 'stationCode' is the column you want to extract
station_code_list = df['stationCode'].tolist()

# %%
station_code_list1=station_code_list[0:2]
station_code_list1
# Out:
# ['AN001', 'AM001']

# %%
# Set the API base URL
url = "https://api.dpird.wa.gov.au/v2/weather/stations/summaries/daily?"
# Headers with API key
headers = {
    "api_key": api_key
}

# %%
# Initialize an empty list to store the data for all stations
all_stations_data = []

# Iterate through each station
for station in station_code_list1:
    # Parameters for the specific station
    params = {
        "endDate": "2023-12-29",
        "group": "api",
        "includeClosed": "false",
        "limit": 225,
        "offset": 0,
        "startDate": "2023-01-01",
        "stationCode": station
    }

    # Make the request for each station
    response = requests.get(url, params=params, headers=headers)
    data = response.json()

    # Extract relevant information for each summary
    for summary in data["collection"][0]["summaries"]:
        date_str = f"{summary['period']['year']}-{summary['period']['month']}-{summary['period']['day']}"
        station_info = {
            "date": pd.to_datetime(date_str),
            "stationCode": data["collection"][0]["stationCode"],
            "stationName": data["collection"][0]["stationName"],
            "rainfall": summary["rainfall"],
            "relativeHumidity": summary["relativeHumidity"]["avg"],
            "airTemperature_avg": summary["airTemperature"]["avg"],
            "wind_avg_speed": summary["wind"][0]["avg"]["speed"]
        }

        # Append the information for the current station and summary to the list
        all_stations_data.append(station_info)

# %%
# Convert the list of dictionaries into a DataFrame
all_stations = pd.DataFrame(all_stations_data)
all_stations
# Out:
#           date stationCode stationName  rainfall  relativeHumidity  \
# 0   2023-01-01       AN001   Allanooka       0.0              66.1
# 1   2023-01-02       AN001   Allanooka       0.0              52.2
# 2   2023-01-03       AN001   Allanooka       0.0              19.1
# 3   2023-01-04       AN001   Allanooka       0.0              22.9
# 4   2023-01-05       AN001   Allanooka       0.0              17.8
# ..         ...         ...         ...       ...               ...
# 445 2023-08-09       AM001      Amelup       6.0              80.7
# 446 2023-08-10       AM001      Amelup       0.0              90.7
# 447 2023-08-11       AM001      Amelup       1.2              85.9
# 448 2023-08-12       AM001      Amelup       0.4              89.6
# 449 2023-08-13       AM001      Amelup       0.0              81.6
#
#      airTemperature_avg  wind_avg_speed
# 0                  21.0           17.93
# 1                  25.2           16.49
# 2                  32.2           24.77
# 3                  32.1           21.67
# 4                  33.3           18.12
# ..                  ...             ...
# 445                 9.6            6.52
# 446                 7.7            3.49
# 447                 9.4            5.53
# 448                10.4           11.45
# 449                10.9            4.62
#
# [450 rows x 7 columns]

# %%
data
# Out:
# {'metadata': {'status': 200,
#   'links': [{'rel': 'self',
#     'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/summaries/daily?endDate=2023-12-29&group=api&includeClosed=false&limit=225&offset=0&startDate=2023-01-01&stationCode=AM001'}],
#   'collection': {'count': 363,
#    'limit': 225,
#    'offset': 0,
#    'links': [{'rel': 'first', 'href': None},
#     {'rel': 'previous', 'href': None},
#     {'rel': 'next',
#      'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/summaries/daily?endDate=2023-12-29&group=api&includeClosed=false&limit=225&startDate=2023-01-01&stationCode=AM001&offset=225'},
#     {'rel': 'last',
#      'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/summaries/daily?endDate=2023-12-29&group=api&includeClosed=false&limit=225&startDate=2023-01-01&stationCode=AM001&offset=225'}]}},
#  'collection': [{'stationCode': 'AM001',
#    'stationName': 'Amelup',
#    'summaries': [{'period': {'from': '2022-12-31T16:00:00Z',
#       'to': '2023-01-01T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 1,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 8.3,
#       'minTime': '2022-12-31T20:15:00Z',
#       'max': 26.3,
#       'maxTime': '2023-01-01T06:33:00Z',
#       'avg': 17},
#      'apparentAirTemperature': {'min': 6.6,
#       'minTime': '2022-12-31T20:15:00Z',
#       'max': 25.2,
#       'maxTime': '2023-01-01T06:46:00Z',
#       'avg': 15.1},
#      'relativeHumidity': {'min': 33.1,
#       'minTime': '2023-01-01T06:34:00Z',
#       'max': 92.5,
#       'maxTime': '2022-12-31T20:37:00Z',
#       'avg': 63},
#      'dewPoint': {'min': 6.8,
#       'minTime': '2022-12-31T20:15:00Z',
#       'max': 10.3,
#       'maxTime': '2023-01-01T04:29:00Z',
#       'avg': 9},
#      'panEvaporation': 7.4,
#      'panEvaporation12AM': 6.8,
#      'evapotranspiration': {'shortCrop': 5.89, 'tallCrop': 7.33},
#      'richardsonUnits': -10,
#      'chillHours': 0,
#      'solarExposure': 28104.4,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.5,
#       'minTime': '2022-12-31T20:26:00Z',
#       'max': 9.6,
#       'maxTime': '2023-01-01T06:33:00Z',
#       'avg': 4.1},
#      'wetBulb': {'min': 7.7,
#       'minTime': '2022-12-31T20:14:00Z',
#       'max': 17,
#       'maxTime': '2023-01-01T07:01:00Z',
#       'avg': 12.86},
#      'wind': [{'height': 3,
#        'avg': {'speed': 8.85},
#        'max': {'speed': 32.58,
#         'time': '2023-01-01T07:12:00Z',
#         'direction': {'degrees': 140, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2022-12-31T19:47:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-01T16:00:00Z',
#       'to': '2023-01-02T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 2,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 6.9,
#       'minTime': '2023-01-01T18:33:00Z',
#       'max': 23.8,
#       'maxTime': '2023-01-02T04:28:00Z',
#       'avg': 16.6},
#      'apparentAirTemperature': {'min': 4.8,
#       'minTime': '2023-01-01T18:35:00Z',
#       'max': 22.1,
#       'maxTime': '2023-01-02T04:04:00Z',
#       'avg': 13.7},
#      'relativeHumidity': {'min': 43.8,
#       'minTime': '2023-01-02T04:15:00Z',
#       'max': 88.2,
#       'maxTime': '2023-01-01T21:17:00Z',
#       'avg': 65.5},
#      'dewPoint': {'min': 4.4,
#       'minTime': '2023-01-01T18:33:00Z',
#       'max': 15.1,
#       'maxTime': '2023-01-03T00:01:00Z',
#       'avg': 9.6},
#      'panEvaporation': 8.9,
#      'panEvaporation12AM': 7.8,
#      'evapotranspiration': {'shortCrop': 6.43, 'tallCrop': 8.07},
#      'richardsonUnits': -5,
#      'chillHours': 0,
#      'solarExposure': 32272.9,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 3, 'startTime': '2023-01-02T07:13:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.8,
#       'minTime': '2023-01-01T19:01:00Z',
#       'max': 7.1,
#       'maxTime': '2023-01-02T04:28:00Z',
#       'avg': 3.6},
#      'wetBulb': {'min': 5.9,
#       'minTime': '2023-01-01T18:33:00Z',
#       'max': 16.8,
#       'maxTime': '2023-01-02T06:08:00Z',
#       'avg': 12.99},
#      'wind': [{'height': 3,
#        'avg': {'speed': 15.09},
#        'max': {'speed': 42.44,
#         'time': '2023-01-02T01:07:00Z',
#         'direction': {'degrees': 113, 'compassPoint': 'ESE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-01T19:48:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-02T16:00:00Z',
#       'to': '2023-01-03T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 3,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 14.5,
#       'minTime': '2023-01-02T20:00:00Z',
#       'max': 22.6,
#       'maxTime': '2023-01-03T06:05:00Z',
#       'avg': 17.7},
#      'apparentAirTemperature': {'min': 12,
#       'minTime': '2023-01-02T13:00:00Z',
#       'max': 20.3,
#       'maxTime': '2023-01-03T04:44:00Z',
#       'avg': 15.1},
#      'relativeHumidity': {'min': 52,
#       'minTime': '2023-01-03T06:05:00Z',
#       'max': 92.3,
#       'maxTime': '2023-01-02T22:18:00Z',
#       'avg': 73.1},
#      'dewPoint': {'min': 9.3,
#       'minTime': '2023-01-02T02:17:00Z',
#       'max': 15.1,
#       'maxTime': '2023-01-03T01:03:00Z',
#       'avg': 12.6},
#      'panEvaporation': 6.3,
#      'panEvaporation12AM': 8.1,
#      'evapotranspiration': {'shortCrop': 4.72, 'tallCrop': 5.96},
#      'richardsonUnits': -12.5,
#      'chillHours': 0,
#      'solarExposure': 23689.8,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 18, 'startTime': '2023-01-03T04:50:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.6,
#       'minTime': '2023-01-02T22:18:00Z',
#       'max': 5.7,
#       'maxTime': '2023-01-03T06:05:00Z',
#       'avg': 2.7},
#      'wetBulb': {'min': 13.5,
#       'minTime': '2023-01-02T18:55:00Z',
#       'max': 17.3,
#       'maxTime': '2023-01-03T04:44:00Z',
#       'avg': 14.98},
#      'wind': [{'height': 3,
#        'avg': {'speed': 17.6},
#        'max': {'speed': 43.02,
#         'time': '2023-01-03T06:31:00Z',
#         'direction': {'degrees': 144, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-02T19:32:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-03T16:00:00Z',
#       'to': '2023-01-04T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 4,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 15.5,
#       'minTime': '2023-01-03T17:05:00Z',
#       'max': 27.2,
#       'maxTime': '2023-01-04T05:49:00Z',
#       'avg': 19.4},
#      'apparentAirTemperature': {'min': 10.3,
#       'minTime': '2023-01-03T12:21:00Z',
#       'max': 24.6,
#       'maxTime': '2023-01-04T05:48:00Z',
#       'avg': 15.7},
#      'relativeHumidity': {'min': 38.5,
#       'minTime': '2023-01-04T05:52:00Z',
#       'max': 84.3,
#       'maxTime': '2023-01-03T01:02:00Z',
#       'avg': 64.6},
#      'dewPoint': {'min': 10.5,
#       'minTime': '2023-01-03T17:05:00Z',
#       'max': 13.7,
#       'maxTime': '2023-01-04T06:06:00Z',
#       'avg': 12.2},
#      'panEvaporation': 9.4,
#      'panEvaporation12AM': 7.2,
#      'evapotranspiration': {'shortCrop': 6.62, 'tallCrop': 8.53},
#      'richardsonUnits': -16,
#      'chillHours': 0,
#      'solarExposure': 29712.5,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 208, 'startTime': '2023-01-04T02:09:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.4,
#       'minTime': '2023-01-03T01:02:00Z',
#       'max': 8.7,
#       'maxTime': '2023-01-04T05:52:00Z',
#       'avg': 3.9},
#      'wetBulb': {'min': 13,
#       'minTime': '2023-01-03T17:11:00Z',
#       'max': 19,
#       'maxTime': '2023-01-04T06:01:00Z',
#       'avg': 15.48},
#      'wind': [{'height': 3,
#        'avg': {'speed': 22.26},
#        'max': {'speed': 50.98,
#         'time': '2023-01-04T09:54:00Z',
#         'direction': {'degrees': 122, 'compassPoint': 'ESE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-03T18:47:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-04T16:00:00Z',
#       'to': '2023-01-05T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 5,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 14.1,
#       'minTime': '2023-01-04T21:10:00Z',
#       'max': 30,
#       'maxTime': '2023-01-05T05:47:00Z',
#       'avg': 20.8},
#      'apparentAirTemperature': {'min': 10.4,
#       'minTime': '2023-01-04T20:55:00Z',
#       'max': 27.1,
#       'maxTime': '2023-01-05T05:29:00Z',
#       'avg': 17.8},
#      'relativeHumidity': {'min': 28.6,
#       'minTime': '2023-01-05T05:33:00Z',
#       'max': 83.3,
#       'maxTime': '2023-01-04T21:24:00Z',
#       'avg': 62.4},
#      'dewPoint': {'min': 11.2,
#       'minTime': '2023-01-04T20:55:00Z',
#       'max': 14.2,
#       'maxTime': '2023-01-05T08:37:00Z',
#       'avg': 12.3},
#      'panEvaporation': 9.8,
#      'panEvaporation12AM': 9.5,
#      'evapotranspiration': {'shortCrop': 7.64, 'tallCrop': 9.95},
#      'richardsonUnits': -15.5,
#      'chillHours': 0,
#      'solarExposure': 32152.4,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 16, 'startTime': '2023-01-05T07:24:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.4,
#       'minTime': '2023-01-04T21:07:00Z',
#       'max': 11.6,
#       'maxTime': '2023-01-05T05:33:00Z',
#       'avg': 4.7},
#      'wetBulb': {'min': 12.7,
#       'minTime': '2023-01-04T21:00:00Z',
#       'max': 19.5,
#       'maxTime': '2023-01-05T08:23:00Z',
#       'avg': 16.08},
#      'wind': [{'height': 3,
#        'avg': {'speed': 19.3},
#        'max': {'speed': 45.43,
#         'time': '2023-01-05T08:39:00Z',
#         'direction': {'degrees': 137, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 1, 'startTime': '2023-01-05T05:47:00Z'},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-04T19:47:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-05T16:00:00Z',
#       'to': '2023-01-06T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 6,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 14.5,
#       'minTime': '2023-01-05T19:05:00Z',
#       'max': 34.1,
#       'maxTime': '2023-01-06T02:58:00Z',
#       'avg': 21},
#      'apparentAirTemperature': {'min': 13.6,
#       'minTime': '2023-01-05T13:26:00Z',
#       'max': 30.8,
#       'maxTime': '2023-01-06T02:56:00Z',
#       'avg': 18.1},
#      'relativeHumidity': {'min': 16.3,
#       'minTime': '2023-01-06T04:10:00Z',
#       'max': 89.5,
#       'maxTime': '2023-01-05T16:11:00Z',
#       'avg': 60},
#      'dewPoint': {'min': 9.4,
#       'minTime': '2023-01-05T04:20:00Z',
#       'max': 15.6,
#       'maxTime': '2023-01-06T06:54:00Z',
#       'avg': 11.1},
#      'panEvaporation': 7,
#      'panEvaporation12AM': 9,
#      'evapotranspiration': {'shortCrop': 6.14, 'tallCrop': 8.49},
#      'richardsonUnits': -15.5,
#      'chillHours': 0,
#      'solarExposure': 19726.6,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 231, 'startTime': '2023-01-06T04:32:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.9,
#       'minTime': '2023-01-05T15:43:00Z',
#       'max': 16.6,
#       'maxTime': '2023-01-06T04:10:00Z',
#       'avg': 5.5},
#      'wetBulb': {'min': 13,
#       'minTime': '2023-01-05T20:35:00Z',
#       'max': 20.4,
#       'maxTime': '2023-01-06T06:49:00Z',
#       'avg': 15.47},
#      'wind': [{'height': 3,
#        'avg': {'speed': 16.63},
#        'max': {'speed': 58.28,
#         'time': '2023-01-06T08:31:00Z',
#         'direction': {'degrees': 230, 'compassPoint': 'SW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 265, 'startTime': '2023-01-06T01:46:00Z'},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-05T21:01:00Z'},
#      'errors': 1,
#      'observations': {'count': 1441, 'percentage': 100.1},
#      'stationAvailability': {'since9AM': 100.1,
#       'to9AM': 100,
#       'since12AM': 100.1},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-06T16:00:00Z',
#       'to': '2023-01-07T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 7,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 14.1,
#       'minTime': '2023-01-06T15:50:00Z',
#       'max': 24.9,
#       'maxTime': '2023-01-07T08:13:00Z',
#       'avg': 17.7},
#      'apparentAirTemperature': {'min': 9.8,
#       'minTime': '2023-01-06T14:26:00Z',
#       'max': 23.9,
#       'maxTime': '2023-01-07T08:13:00Z',
#       'avg': 15.6},
#      'relativeHumidity': {'min': 38.8,
#       'minTime': '2023-01-07T08:14:00Z',
#       'max': 75.9,
#       'maxTime': '2023-01-06T12:59:00Z',
#       'avg': 58.7},
#      'dewPoint': {'min': 4.7,
#       'minTime': '2023-01-06T04:15:00Z',
#       'max': 12.3,
#       'maxTime': '2023-01-07T22:59:00Z',
#       'avg': 9.2},
#      'panEvaporation': 5.5,
#      'panEvaporation12AM': 7.4,
#      'evapotranspiration': {'shortCrop': 4.43, 'tallCrop': 5.61},
#      'richardsonUnits': -11.5,
#      'chillHours': 0,
#      'solarExposure': 19229.1,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 2.1,
#       'minTime': '2023-01-06T12:55:00Z',
#       'max': 8.2,
#       'maxTime': '2023-01-07T08:14:00Z',
#       'avg': 4.3},
#      'wetBulb': {'min': 11.1,
#       'minTime': '2023-01-06T15:50:00Z',
#       'max': 16.7,
#       'maxTime': '2023-01-07T08:08:00Z',
#       'avg': 13.36},
#      'wind': [{'height': 3,
#        'avg': {'speed': 10.15},
#        'max': {'speed': 28.73,
#         'time': '2023-01-06T17:45:00Z',
#         'direction': {'degrees': 213, 'compassPoint': 'SSW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-06T21:21:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100,
#       'to9AM': 100.1,
#       'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-07T16:00:00Z',
#       'to': '2023-01-08T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 8,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 7,
#       'minTime': '2023-01-07T20:45:00Z',
#       'max': 27.8,
#       'maxTime': '2023-01-08T05:08:00Z',
#       'avg': 17.6},
#      'apparentAirTemperature': {'min': 5.1,
#       'minTime': '2023-01-07T20:50:00Z',
#       'max': 26.6,
#       'maxTime': '2023-01-08T04:11:00Z',
#       'avg': 15.8},
#      'relativeHumidity': {'min': 34.7,
#       'minTime': '2023-01-08T05:17:00Z',
#       'max': 93.3,
#       'maxTime': '2023-01-07T22:04:00Z',
#       'avg': 68.3},
#      'dewPoint': {'min': 5.4,
#       'minTime': '2023-01-07T20:45:00Z',
#       'max': 13.7,
#       'maxTime': '2023-01-08T23:46:00Z',
#       'avg': 10.9},
#      'panEvaporation': 8,
#      'panEvaporation12AM': 5.2,
#      'evapotranspiration': {'shortCrop': 6.3, 'tallCrop': 7.56},
#      'richardsonUnits': -7,
#      'chillHours': 0,
#      'solarExposure': 30746.6,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 14, 'startTime': '2023-01-08T06:58:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.5,
#       'minTime': '2023-01-07T20:59:00Z',
#       'max': 9.7,
#       'maxTime': '2023-01-08T05:16:00Z',
#       'avg': 3.6},
#      'wetBulb': {'min': 6.4,
#       'minTime': '2023-01-07T20:45:00Z',
#       'max': 18.9,
#       'maxTime': '2023-01-08T05:46:00Z',
#       'avg': 13.94},
#      'wind': [{'height': 3,
#        'avg': {'speed': 10.9},
#        'max': {'speed': 40.86,
#         'time': '2023-01-08T08:03:00Z',
#         'direction': {'degrees': 132, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-07T20:55:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-08T16:00:00Z',
#       'to': '2023-01-09T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 9,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 14.2,
#       'minTime': '2023-01-08T20:10:00Z',
#       'max': 29,
#       'maxTime': '2023-01-09T04:48:00Z',
#       'avg': 20},
#      'apparentAirTemperature': {'min': 12.7,
#       'minTime': '2023-01-08T20:35:00Z',
#       'max': 27.2,
#       'maxTime': '2023-01-09T04:48:00Z',
#       'avg': 17.5},
#      'relativeHumidity': {'min': 35.4,
#       'minTime': '2023-01-09T04:48:00Z',
#       'max': 91,
#       'maxTime': '2023-01-08T18:56:00Z',
#       'avg': 68.1},
#      'dewPoint': {'min': 10.3,
#       'minTime': '2023-01-08T03:47:00Z',
#       'max': 15.5,
#       'maxTime': '2023-01-10T00:26:00Z',
#       'avg': 13.2},
#      'panEvaporation': 8.9,
#      'panEvaporation12AM': 8.1,
#      'evapotranspiration': {'shortCrop': 6.77, 'tallCrop': 8.54},
#      'richardsonUnits': -13.5,
#      'chillHours': 0,
#      'solarExposure': 30015.3,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 83, 'startTime': '2023-01-09T05:42:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.7,
#       'minTime': '2023-01-08T18:54:00Z',
#       'max': 9.9,
#       'maxTime': '2023-01-09T04:48:00Z',
#       'avg': 3.8},
#      'wetBulb': {'min': 13.1,
#       'minTime': '2023-01-08T20:10:00Z',
#       'max': 19.7,
#       'maxTime': '2023-01-09T05:17:00Z',
#       'avg': 16.19},
#      'wind': [{'height': 3,
#        'avg': {'speed': 17.7},
#        'max': {'speed': 47.02,
#         'time': '2023-01-09T07:38:00Z',
#         'direction': {'degrees': 146, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-08T18:47:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-09T16:00:00Z',
#       'to': '2023-01-10T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 10,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 16.5,
#       'minTime': '2023-01-09T14:25:00Z',
#       'max': 35.9,
#       'maxTime': '2023-01-10T07:59:00Z',
#       'avg': 23.6},
#      'apparentAirTemperature': {'min': 11.2,
#       'minTime': '2023-01-09T14:38:00Z',
#       'max': 34.8,
#       'maxTime': '2023-01-10T07:58:00Z',
#       'avg': 21.6},
#      'relativeHumidity': {'min': 23.5,
#       'minTime': '2023-01-10T07:12:00Z',
#       'max': 89.5,
#       'maxTime': '2023-01-09T22:46:00Z',
#       'avg': 62.4},
#      'dewPoint': {'min': 11.8,
#       'minTime': '2023-01-09T03:25:00Z',
#       'max': 18.6,
#       'maxTime': '2023-01-10T04:12:00Z',
#       'avg': 14.3},
#      'panEvaporation': 6.8,
#      'panEvaporation12AM': 8.1,
#      'evapotranspiration': {'shortCrop': 5.99, 'tallCrop': 8.2},
#      'richardsonUnits': -18,
#      'chillHours': 0,
#      'solarExposure': 17536.3,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 117, 'startTime': '2023-01-10T01:05:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.9,
#       'minTime': '2023-01-09T22:19:00Z',
#       'max': 15,
#       'maxTime': '2023-01-10T07:31:00Z',
#       'avg': 5.5},
#      'wetBulb': {'min': 15,
#       'minTime': '2023-01-09T14:00:00Z',
#       'max': 22.7,
#       'maxTime': '2023-01-10T04:22:00Z',
#       'avg': 18.01},
#      'wind': [{'height': 3,
#        'avg': {'speed': 17.08},
#        'max': {'speed': 66.64,
#         'time': '2023-01-10T02:12:00Z',
#         'direction': {'degrees': 345, 'compassPoint': 'NNW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 370, 'startTime': '2023-01-10T04:18:00Z'},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-09T22:41:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-10T16:00:00Z',
#       'to': '2023-01-11T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 11,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 15.9,
#       'minTime': '2023-01-10T21:21:00Z',
#       'max': 28.4,
#       'maxTime': '2023-01-11T06:52:00Z',
#       'avg': 20.4},
#      'apparentAirTemperature': {'min': 12.2,
#       'minTime': '2023-01-10T17:55:00Z',
#       'max': 28.2,
#       'maxTime': '2023-01-11T06:43:00Z',
#       'avg': 18.4},
#      'relativeHumidity': {'min': 35.8,
#       'minTime': '2023-01-11T06:53:00Z',
#       'max': 87.5,
#       'maxTime': '2023-01-10T19:54:00Z',
#       'avg': 65.9},
#      'dewPoint': {'min': 10.8,
#       'minTime': '2023-01-10T02:12:00Z',
#       'max': 14.7,
#       'maxTime': '2023-01-11T22:29:00Z',
#       'avg': 13.2},
#      'panEvaporation': 7.9,
#      'panEvaporation12AM': 7.6,
#      'evapotranspiration': {'shortCrop': 6.31, 'tallCrop': 7.62},
#      'richardsonUnits': -20.5,
#      'chillHours': 0,
#      'solarExposure': 28522,
#      'rainfall': 3.6,
#      'erosionCondition': {'minutes': 21, 'startTime': '2023-01-10T17:20:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.1,
#       'minTime': '2023-01-10T19:42:00Z',
#       'max': 9.6,
#       'maxTime': '2023-01-11T06:43:00Z',
#       'avg': 4},
#      'wetBulb': {'min': 14.7,
#       'minTime': '2023-01-10T21:21:00Z',
#       'max': 18.9,
#       'maxTime': '2023-01-11T06:54:00Z',
#       'avg': 16.39},
#      'wind': [{'height': 3,
#        'avg': {'speed': 15.44},
#        'max': {'speed': 44.86,
#         'time': '2023-01-10T17:55:00Z',
#         'direction': {'degrees': 215, 'compassPoint': 'SW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-10T01:15:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-11T16:00:00Z',
#       'to': '2023-01-12T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 12,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 11.5,
#       'minTime': '2023-01-11T20:45:00Z',
#       'max': 31.5,
#       'maxTime': '2023-01-12T06:48:00Z',
#       'avg': 19.9},
#      'apparentAirTemperature': {'min': 10.5,
#       'minTime': '2023-01-11T20:30:00Z',
#       'max': 30.9,
#       'maxTime': '2023-01-12T06:48:00Z',
#       'avg': 18.6},
#      'relativeHumidity': {'min': 27,
#       'minTime': '2023-01-12T06:43:00Z',
#       'max': 94.8,
#       'maxTime': '2023-01-11T21:22:00Z',
#       'avg': 68.4},
#      'dewPoint': {'min': 10.4,
#       'minTime': '2023-01-11T20:45:00Z',
#       'max': 16.1,
#       'maxTime': '2023-01-12T22:52:00Z',
#       'avg': 12.8},
#      'panEvaporation': 8,
#      'panEvaporation12AM': 7.6,
#      'evapotranspiration': {'shortCrop': 6.44, 'tallCrop': 7.81},
#      'richardsonUnits': -14.5,
#      'chillHours': 0,
#      'solarExposure': 29667,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 4, 'startTime': '2023-01-12T08:30:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.4,
#       'minTime': '2023-01-11T21:06:00Z',
#       'max': 12.5,
#       'maxTime': '2023-01-12T06:43:00Z',
#       'avg': 4},
#      'wetBulb': {'min': 11,
#       'minTime': '2023-01-11T20:45:00Z',
#       'max': 20.4,
#       'maxTime': '2023-01-12T06:58:00Z',
#       'avg': 15.86},
#      'wind': [{'height': 3,
#        'avg': {'speed': 10.9},
#        'max': {'speed': 42.12,
#         'time': '2023-01-12T08:33:00Z',
#         'direction': {'degrees': 121, 'compassPoint': 'ESE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 78, 'startTime': '2023-01-12T05:31:00Z'},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-11T21:02:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-12T16:00:00Z',
#       'to': '2023-01-13T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 13,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 11,
#       'minTime': '2023-01-12T21:10:00Z',
#       'max': 32.9,
#       'maxTime': '2023-01-13T04:31:00Z',
#       'avg': 21.8},
#      'apparentAirTemperature': {'min': 9.9,
#       'minTime': '2023-01-12T21:05:00Z',
#       'max': 31.5,
#       'maxTime': '2023-01-13T04:22:00Z',
#       'avg': 19.7},
#      'relativeHumidity': {'min': 16.2,
#       'minTime': '2023-01-13T01:52:00Z',
#       'max': 93.4,
#       'maxTime': '2023-01-12T21:51:00Z',
#       'avg': 59.9},
#      'dewPoint': {'min': 7.8,
#       'minTime': '2023-01-13T01:00:00Z',
#       'max': 15.1,
#       'maxTime': '2023-01-13T08:28:00Z',
#       'avg': 11.7},
#      'panEvaporation': 9.4,
#      'panEvaporation12AM': 8.4,
#      'evapotranspiration': {'shortCrop': 7.59, 'tallCrop': 9.56},
#      'richardsonUnits': -17,
#      'chillHours': 0,
#      'solarExposure': 30208.5,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 109, 'startTime': '2023-01-13T06:09:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.5,
#       'minTime': '2023-01-12T21:23:00Z',
#       'max': 15,
#       'maxTime': '2023-01-13T02:43:00Z',
#       'avg': 5.7},
#      'wetBulb': {'min': 10.3,
#       'minTime': '2023-01-12T21:05:00Z',
#       'max': 21,
#       'maxTime': '2023-01-13T06:13:00Z',
#       'avg': 16.08},
#      'wind': [{'height': 3,
#        'avg': {'speed': 13.64},
#        'max': {'speed': 55.33,
#         'time': '2023-01-13T09:59:00Z',
#         'direction': {'degrees': 207, 'compassPoint': 'SSW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 326, 'startTime': '2023-01-13T02:06:00Z'},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-12T19:47:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-13T16:00:00Z',
#       'to': '2023-01-14T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 14,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 11.9,
#       'minTime': '2023-01-13T21:25:00Z',
#       'max': 21.4,
#       'maxTime': '2023-01-14T04:44:00Z',
#       'avg': 16.4},
#      'apparentAirTemperature': {'min': 8.1,
#       'minTime': '2023-01-13T16:49:00Z',
#       'max': 17.2,
#       'maxTime': '2023-01-14T04:41:00Z',
#       'avg': 12},
#      'relativeHumidity': {'min': 37.6,
#       'minTime': '2023-01-14T04:33:00Z',
#       'max': 81.5,
#       'maxTime': '2023-01-13T13:03:00Z',
#       'avg': 53.5},
#      'dewPoint': {'min': 0.9,
#       'minTime': '2023-01-13T01:46:00Z',
#       'max': 8.2,
#       'maxTime': '2023-01-14T17:08:00Z',
#       'avg': 6.8},
#      'panEvaporation': 8.8,
#      'panEvaporation12AM': 9.7,
#      'evapotranspiration': {'shortCrop': 6.17, 'tallCrop': 8.11},
#      'richardsonUnits': -12,
#      'chillHours': 0,
#      'solarExposure': 28773.9,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 52, 'startTime': '2023-01-13T16:49:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.6,
#       'minTime': '2023-01-13T13:03:00Z',
#       'max': 7.6,
#       'maxTime': '2023-01-14T04:33:00Z',
#       'avg': 4.7},
#      'wetBulb': {'min': 9.1,
#       'minTime': '2023-01-13T20:55:00Z',
#       'max': 14.2,
#       'maxTime': '2023-01-14T05:23:00Z',
#       'avg': 11.75},
#      'wind': [{'height': 3,
#        'avg': {'speed': 18.69},
#        'max': {'speed': 48.17,
#         'time': '2023-01-14T04:52:00Z',
#         'direction': {'degrees': 155, 'compassPoint': 'SSE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-13T21:21:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-14T16:00:00Z',
#       'to': '2023-01-15T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 15,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 10.5,
#       'minTime': '2023-01-14T21:25:00Z',
#       'max': 30.5,
#       'maxTime': '2023-01-15T06:34:00Z',
#       'avg': 19.3},
#      'apparentAirTemperature': {'min': 7.7,
#       'minTime': '2023-01-14T21:07:00Z',
#       'max': 28.3,
#       'maxTime': '2023-01-15T06:22:00Z',
#       'avg': 16.2},
#      'relativeHumidity': {'min': 20.9,
#       'minTime': '2023-01-15T06:35:00Z',
#       'max': 75,
#       'maxTime': '2023-01-14T20:02:00Z',
#       'avg': 55.6},
#      'dewPoint': {'min': 5.5,
#       'minTime': '2023-01-14T03:41:00Z',
#       'max': 14.2,
#       'maxTime': '2023-01-15T18:36:00Z',
#       'avg': 9.1},
#      'panEvaporation': 9.1,
#      'panEvaporation12AM': 8.9,
#      'evapotranspiration': {'shortCrop': 7.21, 'tallCrop': 9.28},
#      'richardsonUnits': -8.5,
#      'chillHours': 0,
#      'solarExposure': 30522.3,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 14, 'startTime': '2023-01-15T06:49:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.9,
#       'minTime': '2023-01-14T19:55:00Z',
#       'max': 13.8,
#       'maxTime': '2023-01-15T06:35:00Z',
#       'avg': 5.3},
#      'wetBulb': {'min': 8.5,
#       'minTime': '2023-01-14T21:25:00Z',
#       'max': 18.6,
#       'maxTime': '2023-01-15T06:49:00Z',
#       'avg': 13.93},
#      'wind': [{'height': 3,
#        'avg': {'speed': 15.12},
#        'max': {'speed': 41.36,
#         'time': '2023-01-15T10:02:00Z',
#         'direction': {'degrees': 133, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 27, 'startTime': '2023-01-15T06:16:00Z'},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-14T20:46:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-15T16:00:00Z',
#       'to': '2023-01-16T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 16,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 13.6,
#       'minTime': '2023-01-15T19:50:00Z',
#       'max': 24.8,
#       'maxTime': '2023-01-16T04:25:00Z',
#       'avg': 18.1},
#      'apparentAirTemperature': {'min': 12,
#       'minTime': '2023-01-15T21:09:00Z',
#       'max': 20.3,
#       'maxTime': '2023-01-16T02:54:00Z',
#       'avg': 14.5},
#      'relativeHumidity': {'min': 33,
#       'minTime': '2023-01-16T04:15:00Z',
#       'max': 91.3,
#       'maxTime': '2023-01-15T20:34:00Z',
#       'avg': 61},
#      'dewPoint': {'min': 5.6,
#       'minTime': '2023-01-15T06:35:00Z',
#       'max': 12.3,
#       'maxTime': '2023-01-16T01:42:00Z',
#       'avg': 9.7},
#      'panEvaporation': 8.2,
#      'panEvaporation12AM': 8.7,
#      'evapotranspiration': {'shortCrop': 6.16, 'tallCrop': 8.36},
#      'richardsonUnits': -15,
#      'chillHours': 0,
#      'solarExposure': 26537.2,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 138, 'startTime': '2023-01-16T02:51:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.7,
#       'minTime': '2023-01-15T20:23:00Z',
#       'max': 9.2,
#       'maxTime': '2023-01-16T04:15:00Z',
#       'avg': 4.3},
#      'wetBulb': {'min': 12.6,
#       'minTime': '2023-01-15T19:50:00Z',
#       'max': 16.8,
#       'maxTime': '2023-01-16T05:04:00Z',
#       'avg': 13.79},
#      'wind': [{'height': 3,
#        'avg': {'speed': 18.5},
#        'max': {'speed': 51.34,
#         'time': '2023-01-16T08:28:00Z',
#         'direction': {'degrees': 220, 'compassPoint': 'SW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-15T18:17:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-16T16:00:00Z',
#       'to': '2023-01-17T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 17,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 10.4,
#       'minTime': '2023-01-16T20:35:00Z',
#       'max': 22.1,
#       'maxTime': '2023-01-17T05:41:00Z',
#       'avg': 16.2},
#      'apparentAirTemperature': {'min': 7.2,
#       'minTime': '2023-01-16T20:30:00Z',
#       'max': 18,
#       'maxTime': '2023-01-17T03:42:00Z',
#       'avg': 12.3},
#      'relativeHumidity': {'min': 33.5,
#       'minTime': '2023-01-17T05:48:00Z',
#       'max': 74.6,
#       'maxTime': '2023-01-16T22:21:00Z',
#       'avg': 53.1},
#      'dewPoint': {'min': 4.8,
#       'minTime': '2023-01-16T10:49:00Z',
#       'max': 8.3,
#       'maxTime': '2023-01-17T22:46:00Z',
#       'avg': 6.2},
#      'panEvaporation': 7.8,
#      'panEvaporation12AM': 8.8,
#      'evapotranspiration': {'shortCrop': 5.75, 'tallCrop': 7.63},
#      'richardsonUnits': -9.5,
#      'chillHours': 0,
#      'solarExposure': 25987.4,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 3, 'startTime': '2023-01-17T01:35:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 2,
#       'minTime': '2023-01-16T20:46:00Z',
#       'max': 8.5,
#       'maxTime': '2023-01-17T05:41:00Z',
#       'avg': 4.8},
#      'wetBulb': {'min': 8.3,
#       'minTime': '2023-01-16T20:20:00Z',
#       'max': 13.7,
#       'maxTime': '2023-01-17T05:41:00Z',
#       'avg': 11.39},
#      'wind': [{'height': 3,
#        'avg': {'speed': 15.31},
#        'max': {'speed': 44.17,
#         'time': '2023-01-17T06:35:00Z',
#         'direction': {'degrees': 141, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-16T20:56:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-17T16:00:00Z',
#       'to': '2023-01-18T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 18,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 9.2,
#       'minTime': '2023-01-17T21:30:00Z',
#       'max': 23.2,
#       'maxTime': '2023-01-18T05:38:00Z',
#       'avg': 17},
#      'apparentAirTemperature': {'min': 7.3,
#       'minTime': '2023-01-17T21:15:00Z',
#       'max': 19.6,
#       'maxTime': '2023-01-18T04:33:00Z',
#       'avg': 13.2},
#      'relativeHumidity': {'min': 36,
#       'minTime': '2023-01-18T04:35:00Z',
#       'max': 77.2,
#       'maxTime': '2023-01-17T21:48:00Z',
#       'avg': 56.7},
#      'dewPoint': {'min': 4.8,
#       'minTime': '2023-01-17T02:35:00Z',
#       'max': 11,
#       'maxTime': '2023-01-18T18:54:00Z',
#       'avg': 7.9},
#      'panEvaporation': 8.2,
#      'panEvaporation12AM': 7.3,
#      'evapotranspiration': {'shortCrop': 6.17, 'tallCrop': 8.15},
#      'richardsonUnits': -8.5,
#      'chillHours': 0,
#      'solarExposure': 27505.6,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 54, 'startTime': '2023-01-18T04:51:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.7,
#       'minTime': '2023-01-17T21:35:00Z',
#       'max': 8.3,
#       'maxTime': '2023-01-18T04:31:00Z',
#       'avg': 4.5},
#      'wetBulb': {'min': 7.4,
#       'minTime': '2023-01-17T21:20:00Z',
#       'max': 15.1,
#       'maxTime': '2023-01-18T05:38:00Z',
#       'avg': 12.44},
#      'wind': [{'height': 3,
#        'avg': {'speed': 17.02},
#        'max': {'speed': 49.36,
#         'time': '2023-01-18T06:23:00Z',
#         'direction': {'degrees': 115, 'compassPoint': 'ESE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-01-17T21:16:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-18T16:00:00Z',
#       'to': '2023-01-19T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 19,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 13,
#       'minTime': '2023-01-18T21:32:00Z',
#       'max': 27.5,
#       'maxTime': '2023-01-19T06:09:00Z',
#       'avg': 19},
#      'apparentAirTemperature': {'min': 8.8,
#       'minTime': '2023-01-18T21:25:00Z',
#       'max': 24.4,
#       'maxTime': '2023-01-19T05:28:00Z',
#       'avg': 15.1},
#      'relativeHumidity': {'min': 30.7,
#       'minTime': '2023-01-19T04:59:00Z',
#       'max': 78.8,
#       'maxTime': '2023-01-18T18:21:00Z',
#       'avg': 58.2},
#      'dewPoint': {'min': 6.6,
#       'minTime': '2023-01-18T01:53:00Z',
#       'max': 13.4,
#       'maxTime': '2023-01-19T19:14:00Z',
#       'avg': 9.7},
#      'panEvaporation': 9.8,
#      'panEvaporation12AM': 8.8,
#      'evapotranspiration': {'shortCrop': 7.37, 'tallCrop': 9.7},
#      'richardsonUnits': -12,
#      'chillHours': 0,
#      'solarExposure': 30794.5,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 104, 'startTime': '2023-01-19T07:08:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.8,
#       'minTime': '2023-01-18T17:43:00Z',
#       'max': 10.4,
#       'maxTime': '2023-01-19T06:09:00Z',
#       'avg': 4.9},
#      'wetBulb': {'min': 10.3,
#       'minTime': '2023-01-18T21:06:00Z',
#       'max': 17.2,
#       'maxTime': '2023-01-19T06:07:00Z',
#       'avg': 14.11},
#      'wind': [{'height': 3,
#        'avg': {'speed': 20.03},
#        'max': {'speed': 54.54,
#         'time': '2023-01-19T11:03:00Z',
#         'direction': {'degrees': 125, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-18T18:32:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-19T16:00:00Z',
#       'to': '2023-01-20T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 20,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 14.9,
#       'minTime': '2023-01-19T15:10:00Z',
#       'max': 28.8,
#       'maxTime': '2023-01-20T05:44:00Z',
#       'avg': 20.4},
#      'apparentAirTemperature': {'min': 11.3,
#       'minTime': '2023-01-19T13:21:00Z',
#       'max': 26.3,
#       'maxTime': '2023-01-20T05:40:00Z',
#       'avg': 17},
#      'relativeHumidity': {'min': 33.7,
#       'minTime': '2023-01-20T04:28:00Z',
#       'max': 84.8,
#       'maxTime': '2023-01-19T16:06:00Z',
#       'avg': 63},
#      'dewPoint': {'min': 8,
#       'minTime': '2023-01-19T04:50:00Z',
#       'max': 13.5,
#       'maxTime': '2023-01-20T17:24:00Z',
#       'avg': 12.3},
#      'panEvaporation': 9.1,
#      'panEvaporation12AM': 9.1,
#      'evapotranspiration': {'shortCrop': 7.29, 'tallCrop': 9.56},
#      'richardsonUnits': -15,
#      'chillHours': 0,
#      'solarExposure': 30203.3,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 118, 'startTime': '2023-01-19T23:14:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.3,
#       'minTime': '2023-01-19T15:39:00Z',
#       'max': 10.1,
#       'maxTime': '2023-01-20T04:28:00Z',
#       'avg': 4.5},
#      'wetBulb': {'min': 13.3,
#       'minTime': '2023-01-19T14:06:00Z',
#       'max': 18.9,
#       'maxTime': '2023-01-20T05:44:00Z',
#       'avg': 15.92},
#      'wind': [{'height': 3,
#        'avg': {'speed': 21.19},
#        'max': {'speed': 48.64,
#         'time': '2023-01-20T09:01:00Z',
#         'direction': {'degrees': 139, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-19T18:56:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-20T16:00:00Z',
#       'to': '2023-01-21T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 21,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 14.8,
#       'minTime': '2023-01-20T21:15:00Z',
#       'max': 30,
#       'maxTime': '2023-01-21T05:12:00Z',
#       'avg': 20.7},
#      'apparentAirTemperature': {'min': 11.3,
#       'minTime': '2023-01-20T21:43:00Z',
#       'max': 26.8,
#       'maxTime': '2023-01-21T05:10:00Z',
#       'avg': 17.6},
#      'relativeHumidity': {'min': 33.8,
#       'minTime': '2023-01-21T05:13:00Z',
#       'max': 88.9,
#       'maxTime': '2023-01-20T19:57:00Z',
#       'avg': 65.1},
#      'dewPoint': {'min': 10.4,
#       'minTime': '2023-01-20T03:30:00Z',
#       'max': 14.6,
#       'maxTime': '2023-01-21T15:31:00Z',
#       'avg': 13.1},
#      'panEvaporation': 8.2,
#      'panEvaporation12AM': 9.1,
#      'evapotranspiration': {'shortCrop': 6.67, 'tallCrop': 8.99},
#      'richardsonUnits': -14.5,
#      'chillHours': 0,
#      'solarExposure': 26032.6,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 124, 'startTime': '2023-01-21T00:22:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.9,
#       'minTime': '2023-01-20T19:31:00Z',
#       'max': 10.5,
#       'maxTime': '2023-01-21T05:13:00Z',
#       'avg': 4.3},
#      'wetBulb': {'min': 13.5,
#       'minTime': '2023-01-20T21:20:00Z',
#       'max': 19.7,
#       'maxTime': '2023-01-21T07:32:00Z',
#       'avg': 16.4},
#      'wind': [{'height': 3,
#        'avg': {'speed': 20.62},
#        'max': {'speed': 52.45,
#         'time': '2023-01-21T08:10:00Z',
#         'direction': {'degrees': 116, 'compassPoint': 'ESE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 3, 'startTime': '2023-01-21T05:12:00Z'},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-20T18:48:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-01-21T16:00:00Z',
#       'to': '2023-01-22T16:00:00Z',
#       'year': 2023,
#       'month': 1,
#       'day': 22,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 16,
#       'minTime': '2023-01-21T21:25:00Z',
#       'max': 27.2,
#       'maxTime': '2023-01-22T08:51:00Z',
#       'avg': 20.2},
#      'apparentAirTemperature': {'min': 10.6,
#       'minTime': '2023-01-21T22:28:00Z',
#       'max': 25.5,
#       'maxTime': '2023-01-22T08:49:00Z',
#       'avg': 17.9},
#      'relativeHumidity': {'min': 41.7,
#       'minTime': '2023-01-22T09:17:00Z',
#       'max': 87.1,
#       'maxTime': '2023-01-21T17:52:00Z',
#       'avg': 69.4},
#      'dewPoint': {'min': 11.7,
#       'minTime': '2023-01-21T04:20:00Z',
#       'max': 16.9,
#       'maxTime': '2023-01-22T23:42:00Z',
#       'avg': 14},
#      'panEvaporation': 4.8,
#      'panEvaporation12AM': 7.9,
#      'evapotranspiration': {'shortCrop': 4.19, 'tallCrop': 5.69},
#      'richardsonUnits': -18.5,
#      'chillHours': 0,
#      'solarExposure': 15686.6,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 62, 'startTime': '2023-01-21T19:18:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 1.1,
#       'minTime': '2023-01-21T17:42:00Z',
#       'max': 8.2,
#       'maxTime': '2023-01-22T09:17:00Z',
#       'avg': 3.4},
#      'wetBulb': {'min': 14.6,
#       'minTime': '2023-01-21T21:25:00Z',
#       'max': 20,
#       'maxTime': '2023-01-22T07:16:00Z',
#       'avg': 16.78},
#      'wind': [{'height': 3,
#        'avg': {'speed': 18.44},
#        'max': {'speed': 53.06,
#         'time': '2023-01-21T22:42:00Z',
#         'direction': {'degrees': 111, 'compassPoint': 'ESE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-01-21T18:47:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
# ...
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.1,
#       'minTime': '2023-08-06T00:24:00Z',
#       'max': 6.3,
#       'maxTime': '2023-08-06T07:15:00Z',
#       'avg': 1.9},
#      'wetBulb': {'min': 0,
#       'minTime': '2023-08-05T22:50:00Z',
#       'max': 14.5,
#       'maxTime': '2023-08-06T06:54:00Z',
#       'avg': 7.43},
#      'wind': [{'height': 3,
#        'avg': {'speed': 4.09},
#        'max': {'speed': 14.15,
#         'time': '2023-08-06T13:18:00Z',
#         'direction': {'degrees': 111, 'compassPoint': 'ESE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 331, 'startTime': '2023-08-05T17:15:00Z'},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-08-05T21:41:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-08-06T16:00:00Z',
#       'to': '2023-08-07T16:00:00Z',
#       'year': 2023,
#       'month': 8,
#       'day': 7,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 7.6,
#       'minTime': '2023-08-06T01:01:00Z',
#       'max': 22.9,
#       'maxTime': '2023-08-07T05:41:00Z',
#       'avg': 15.5},
#      'apparentAirTemperature': {'min': 5.9,
#       'minTime': '2023-08-06T01:05:00Z',
#       'max': 23.1,
#       'maxTime': '2023-08-07T06:24:00Z',
#       'avg': 14.5},
#      'relativeHumidity': {'min': 58,
#       'minTime': '2023-08-07T05:52:00Z',
#       'max': 96.6,
#       'maxTime': '2023-08-06T21:44:00Z',
#       'avg': 80.1},
#      'dewPoint': {'min': 5.7,
#       'minTime': '2023-08-06T11:26:00Z',
#       'max': 15.8,
#       'maxTime': '2023-08-07T03:41:00Z',
#       'avg': 11.8},
#      'panEvaporation': 2.8,
#      'panEvaporation12AM': 2.7,
#      'evapotranspiration': {'shortCrop': 2.36, 'tallCrop': 2.98},
#      'richardsonUnits': 3.5,
#      'chillHours': 0,
#      'solarExposure': 12065.9,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.2,
#       'minTime': '2023-08-06T21:44:00Z',
#       'max': 4.9,
#       'maxTime': '2023-08-07T05:52:00Z',
#       'avg': 1.9},
#      'wetBulb': {'min': 7.2,
#       'minTime': '2023-08-06T01:01:00Z',
#       'max': 18.5,
#       'maxTime': '2023-08-07T03:41:00Z',
#       'avg': 13.55},
#      'wind': [{'height': 3,
#        'avg': {'speed': 8.15},
#        'max': {'speed': 33.73,
#         'time': '2023-08-07T07:12:00Z',
#         'direction': {'degrees': 302, 'compassPoint': 'WNW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.9,
#       'minVoltageDateTime': '2023-08-06T19:48:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-08-07T16:00:00Z',
#       'to': '2023-08-08T16:00:00Z',
#       'year': 2023,
#       'month': 8,
#       'day': 8,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 12.9,
#       'minTime': '2023-08-07T17:40:00Z',
#       'max': 16.5,
#       'maxTime': '2023-08-08T01:36:00Z',
#       'avg': 13.3},
#      'apparentAirTemperature': {'min': 12.1,
#       'minTime': '2023-08-07T16:40:00Z',
#       'max': 15.7,
#       'maxTime': '2023-08-08T01:32:00Z',
#       'avg': 11.4},
#      'relativeHumidity': {'min': 67.8,
#       'minTime': '2023-08-08T10:34:00Z',
#       'max': 93.7,
#       'maxTime': '2023-08-07T19:14:00Z',
#       'avg': 84.5},
#      'dewPoint': {'min': 11,
#       'minTime': '2023-08-07T01:02:00Z',
#       'max': 14.6,
#       'maxTime': '2023-08-08T06:01:00Z',
#       'avg': 10.7},
#      'panEvaporation': 0.7,
#      'panEvaporation12AM': 2.7,
#      'evapotranspiration': {'shortCrop': 0.83, 'tallCrop': 1.17},
#      'richardsonUnits': -9.5,
#      'chillHours': 0,
#      'solarExposure': 3255.9,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 7, 'startTime': '2023-08-08T06:19:00Z'},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.5,
#       'minTime': '2023-08-07T18:19:00Z',
#       'max': 2.6,
#       'maxTime': '2023-08-08T10:30:00Z',
#       'avg': 1.2},
#      'wetBulb': {'min': 12.2,
#       'minTime': '2023-08-07T17:40:00Z',
#       'max': 15.4,
#       'maxTime': '2023-08-08T06:01:00Z',
#       'avg': 12.04},
#      'wind': [{'height': 3,
#        'avg': {'speed': 10.96},
#        'max': {'speed': 48.38,
#         'time': '2023-08-08T06:19:00Z',
#         'direction': {'degrees': 268, 'compassPoint': 'W'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.9,
#       'minVoltageDateTime': '2023-08-07T19:50:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-08-08T16:00:00Z',
#       'to': '2023-08-09T16:00:00Z',
#       'year': 2023,
#       'month': 8,
#       'day': 9,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 3.2,
#       'minTime': '2023-08-08T22:20:00Z',
#       'max': 16,
#       'maxTime': '2023-08-09T06:24:00Z',
#       'avg': 9.6},
#      'apparentAirTemperature': {'min': 0.7,
#       'minTime': '2023-08-08T22:20:00Z',
#       'max': 14.3,
#       'maxTime': '2023-08-09T05:24:00Z',
#       'avg': 7.4},
#      'relativeHumidity': {'min': 54.2,
#       'minTime': '2023-08-09T06:38:00Z',
#       'max': 95.2,
#       'maxTime': '2023-08-08T23:32:00Z',
#       'avg': 80.7},
#      'dewPoint': {'min': 2.1,
#       'minTime': '2023-08-08T22:20:00Z',
#       'max': 8.9,
#       'maxTime': '2023-08-09T01:37:00Z',
#       'avg': 6.1},
#      'panEvaporation': 2.1,
#      'panEvaporation12AM': 0.8,
#      'evapotranspiration': {'shortCrop': 1.78, 'tallCrop': 2.19},
#      'richardsonUnits': 12.5,
#      'chillHours': 7,
#      'solarExposure': 12260.9,
#      'rainfall': 6,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.3,
#       'minTime': '2023-08-08T22:27:00Z',
#       'max': 4.4,
#       'maxTime': '2023-08-09T06:38:00Z',
#       'avg': 1.6},
#      'wetBulb': {'min': 2.8,
#       'minTime': '2023-08-08T22:20:00Z',
#       'max': 12.1,
#       'maxTime': '2023-08-09T05:57:00Z',
#       'avg': 7.98},
#      'wind': [{'height': 3,
#        'avg': {'speed': 6.52},
#        'max': {'speed': 21.78,
#         'time': '2023-08-08T16:34:00Z',
#         'direction': {'degrees': 300, 'compassPoint': 'WNW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.7,
#       'minVoltageDateTime': '2023-08-08T19:48:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-08-09T16:00:00Z',
#       'to': '2023-08-10T16:00:00Z',
#       'year': 2023,
#       'month': 8,
#       'day': 10,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 2.6,
#       'minTime': '2023-08-09T20:10:00Z',
#       'max': 11.9,
#       'maxTime': '2023-08-10T06:26:00Z',
#       'avg': 7.7},
#      'apparentAirTemperature': {'min': -0.1,
#       'minTime': '2023-08-09T20:10:00Z',
#       'max': 10.9,
#       'maxTime': '2023-08-10T06:26:00Z',
#       'avg': 6.1},
#      'relativeHumidity': {'min': 77.3,
#       'minTime': '2023-08-10T06:55:00Z',
#       'max': 96.1,
#       'maxTime': '2023-08-09T19:47:00Z',
#       'avg': 90.7},
#      'dewPoint': {'min': 1.8,
#       'minTime': '2023-08-09T20:10:00Z',
#       'max': 8.6,
#       'maxTime': '2023-08-10T08:31:00Z',
#       'avg': 6.2},
#      'panEvaporation': 0.3,
#      'panEvaporation12AM': 2,
#      'evapotranspiration': {'shortCrop': 0.48, 'tallCrop': 0.65},
#      'richardsonUnits': 15,
#      'chillHours': 10,
#      'solarExposure': 4043.5,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.2,
#       'minTime': '2023-08-09T19:27:00Z',
#       'max': 1.7,
#       'maxTime': '2023-08-10T06:20:00Z',
#       'avg': 0.6},
#      'wetBulb': {'min': 2.3,
#       'minTime': '2023-08-09T20:10:00Z',
#       'max': 10.3,
#       'maxTime': '2023-08-10T06:26:00Z',
#       'avg': 7.03},
#      'wind': [{'height': 3,
#        'avg': {'speed': 3.49},
#        'max': {'speed': 13.46,
#         'time': '2023-08-10T07:22:00Z',
#         'direction': {'degrees': 267, 'compassPoint': 'W'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.9,
#       'minVoltageDateTime': '2023-08-09T19:50:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-08-10T16:00:00Z',
#       'to': '2023-08-11T16:00:00Z',
#       'year': 2023,
#       'month': 8,
#       'day': 11,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 3.8,
#       'minTime': '2023-08-10T23:15:00Z',
#       'max': 17.7,
#       'maxTime': '2023-08-11T07:26:00Z',
#       'avg': 9.4},
#      'apparentAirTemperature': {'min': 1.7,
#       'minTime': '2023-08-10T23:12:00Z',
#       'max': 15.9,
#       'maxTime': '2023-08-11T04:33:00Z',
#       'avg': 7.6},
#      'relativeHumidity': {'min': 51.8,
#       'minTime': '2023-08-11T07:22:00Z',
#       'max': 98.3,
#       'maxTime': '2023-08-11T00:17:00Z',
#       'avg': 85.9},
#      'dewPoint': {'min': 3.4,
#       'minTime': '2023-08-10T23:05:00Z',
#       'max': 12.9,
#       'maxTime': '2023-08-11T03:15:00Z',
#       'avg': 6.9},
#      'panEvaporation': 2.1,
#      'panEvaporation12AM': 0.3,
#      'evapotranspiration': {'shortCrop': 1.74, 'tallCrop': 2.14},
#      'richardsonUnits': 19.5,
#      'chillHours': 11,
#      'solarExposure': 12085.1,
#      'rainfall': 1.2,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.1,
#       'minTime': '2023-08-10T19:41:00Z',
#       'max': 4.9,
#       'maxTime': '2023-08-11T07:20:00Z',
#       'avg': 1.2},
#      'wetBulb': {'min': 3.6,
#       'minTime': '2023-08-10T23:15:00Z',
#       'max': 13.6,
#       'maxTime': '2023-08-11T03:29:00Z',
#       'avg': 8.24},
#      'wind': [{'height': 3,
#        'avg': {'speed': 5.53},
#        'max': {'speed': 28.94,
#         'time': '2023-08-11T06:37:00Z',
#         'direction': {'degrees': 170, 'compassPoint': 'S'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.8,
#       'minVoltageDateTime': '2023-08-10T19:35:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-08-11T16:00:00Z',
#       'to': '2023-08-12T16:00:00Z',
#       'year': 2023,
#       'month': 8,
#       'day': 12,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 6.6,
#       'minTime': '2023-08-11T12:35:00Z',
#       'max': 12.8,
#       'maxTime': '2023-08-12T06:06:00Z',
#       'avg': 10.4},
#      'apparentAirTemperature': {'min': 4.3,
#       'minTime': '2023-08-11T12:35:00Z',
#       'max': 11.1,
#       'maxTime': '2023-08-13T00:48:00Z',
#       'avg': 7.9},
#      'relativeHumidity': {'min': 80.1,
#       'minTime': '2023-08-12T05:02:00Z',
#       'max': 98.6,
#       'maxTime': '2023-08-11T02:24:00Z',
#       'avg': 89.6},
#      'dewPoint': {'min': 4.9,
#       'minTime': '2023-08-11T12:32:00Z',
#       'max': 10.8,
#       'maxTime': '2023-08-13T00:58:00Z',
#       'avg': 8.8},
#      'panEvaporation': 1.5,
#      'panEvaporation12AM': 2.1,
#      'evapotranspiration': {'shortCrop': 1.3, 'tallCrop': 1.53},
#      'richardsonUnits': 10,
#      'chillHours': 0,
#      'solarExposure': 10627.6,
#      'rainfall': 0.4,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.1,
#       'minTime': '2023-08-11T01:01:00Z',
#       'max': 1.6,
#       'maxTime': '2023-08-12T05:02:00Z',
#       'avg': 0.8},
#      'wetBulb': {'min': 5.9,
#       'minTime': '2023-08-11T12:35:00Z',
#       'max': 11.6,
#       'maxTime': '2023-08-12T06:06:00Z',
#       'avg': 9.65},
#      'wind': [{'height': 3,
#        'avg': {'speed': 11.45},
#        'max': {'speed': 37.26,
#         'time': '2023-08-12T08:36:00Z',
#         'direction': {'degrees': 128, 'compassPoint': 'SE'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.9,
#       'minVoltageDateTime': '2023-08-11T22:47:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]},
#     {'period': {'from': '2023-08-12T16:00:00Z',
#       'to': '2023-08-13T16:00:00Z',
#       'year': 2023,
#       'month': 8,
#       'day': 13,
#       'hour': None,
#       'minute': None},
#      'airTemperature': {'min': 7.1,
#       'minTime': '2023-08-12T18:45:00Z',
#       'max': 17.4,
#       'maxTime': '2023-08-13T06:44:00Z',
#       'avg': 10.9},
#      'apparentAirTemperature': {'min': 5.3,
#       'minTime': '2023-08-12T19:05:00Z',
#       'max': 16.3,
#       'maxTime': '2023-08-13T05:28:00Z',
#       'avg': 9.5},
#      'relativeHumidity': {'min': 51.8,
#       'minTime': '2023-08-13T07:05:00Z',
#       'max': 96.6,
#       'maxTime': '2023-08-12T23:13:00Z',
#       'avg': 81.6},
#      'dewPoint': {'min': 6.1,
#       'minTime': '2023-08-12T18:45:00Z',
#       'max': 11.4,
#       'maxTime': '2023-08-13T03:33:00Z',
#       'avg': 7.6},
#      'panEvaporation': 2.7,
#      'panEvaporation12AM': 1.6,
#      'evapotranspiration': {'shortCrop': 2.18, 'tallCrop': 2.5},
#      'richardsonUnits': 15,
#      'chillHours': 0,
#      'solarExposure': 14779.8,
#      'rainfall': 0,
#      'erosionCondition': {'minutes': 0, 'startTime': None},
#      'soilTemperature': None,
#      'deltaT': {'min': 0.2,
#       'minTime': '2023-08-12T23:11:00Z',
#       'max': 4.8,
#       'maxTime': '2023-08-13T06:49:00Z',
#       'avg': 1.6},
#      'wetBulb': {'min': 6.7,
#       'minTime': '2023-08-12T18:45:00Z',
#       'max': 13.7,
#       'maxTime': '2023-08-13T04:12:00Z',
#       'avg': 9.35},
#      'wind': [{'height': 3,
#        'avg': {'speed': 4.62},
#        'max': {'speed': 23.83,
#         'time': '2023-08-13T06:43:00Z',
#         'direction': {'degrees': 323, 'compassPoint': 'NW'}}}],
#      'barometricPressure': None,
#      'frostCondition': {'minutes': 0, 'startTime': None},
#      'heatCondition': {'minutes': 0, 'startTime': None},
#      'battery': {'minVoltage': 12.9,
#       'minVoltageDateTime': '2023-08-12T19:20:00Z'},
#      'errors': 0,
#      'observations': {'count': 1440, 'percentage': 100},
#      'stationAvailability': {'since9AM': 100, 'to9AM': 100, 'since12AM': 100},
#      'links': [{'rel': 'self',
#        'href': 'https://api.dpird.wa.gov.au/v2/weather/stations/AM001'}]}]}]}
