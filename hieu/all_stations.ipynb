# %% [markdown]
# ## Prepare and Clean the Data

# %%
# Dependencies
from pathlib import Path
import pandas as pd
import pprint
import os
import requests

# %%
# Load the csv file
file_path = Path("Resources/DPIRDWeatherStations.csv")

# Read the csv file
stations_df = pd.read_csv(file_path)

# Display data
stations_df.head()
# Out:
#   stationCode  stationName   latitude   longitude  altitude  \
# 0       AN001    Allanooka -29.063612  114.997161     131.0
# 1       AM001       Amelup -34.270827  118.268523     200.0
# 2       SH002      Babakin -32.125480  118.004060     313.0
# 3          BA  Badgingarra -30.338049  115.539491     284.0
# 4       BP001     Balingup -33.796200  116.063980     227.0
#
#                                                owner ownerCode   startDate  \
# 0  WA Department of Primary Industries and Region...     DPIRD  2012-06-19
# 1  WA Department of Primary Industries and Region...     DPIRD  2019-10-09
# 2  WA Department of Primary Industries and Region...     DPIRD  2016-06-22
# 3  WA Department of Primary Industries and Region...     DPIRD  2008-11-19
# 4  WA Department of Primary Industries and Region...     DPIRD  2014-10-24
#
#   endDate  probeHeight  ...  capabilities.etoTall capabilities.frostCondition  \
# 0     NaN         1.25  ...                   Yes                         Yes
# 1     NaN         1.25  ...                   Yes                         Yes
# 2     NaN         1.25  ...                   Yes                         Yes
# 3     NaN         1.25  ...                   Yes                         Yes
# 4     NaN         1.25  ...                   Yes                         Yes
#
#   capabilities.heatCondition capabilities.windErosionCondition  \
# 0                        Yes                               Yes
# 1                        Yes                               Yes
# 2                        Yes                               Yes
# 3                        Yes                               Yes
# 4                        Yes                               Yes
#
#   capabilities.richardsonUnit capabilities.chillHour online status  \
# 0                         Yes                    Yes    Yes   open
# 1                         Yes                    Yes    Yes   open
# 2                         Yes                    Yes    Yes   open
# 3                         Yes                    Yes    Yes   open
# 4                         Yes                    Yes    Yes   open
#
#            comments jobNumber
# 0               NaN     J3121
# 1  WMO number 99449     P0011
# 2               NaN     J3451
# 3               NaN     J3315
# 4               NaN     J3461
#
# [5 rows x 38 columns]

# %%
# Count the number of unique stations
num_unique_stations = stations_df['stationCode'].nunique()

# Print number of stations
print(f"Number of Unique Stations: {num_unique_stations}")
# Out:
# Number of Unique Stations: 225

# %%
# Listing all the station codes
all_stations = stations_df['stationCode']
all_stations
# Out:
# 0      AN001
# 1      AM001
# 2      SH002
# 3         BA
# 4      BP001
#        ...
# 220       YS
# 221    YE001
# 222    YU001
# 223    YU002
# 224    YU003
# Name: stationCode, Length: 225, dtype: object

# %%
# API endpoint
url = "https://api.dpird.wa.gov.au/v2/weather/stations/rainfall"

# %%
# Parameters
params = {
    "startDate": "2022-11-01",  
    "endDate": "2023-11-30",    
    "stationCode": ",".join(all_stations),  
    "limit": 225  
}

# API key
api_key = "UyyNRAlaRV91Y3jCe4Ce9Vx922b2KY6R"

# Headers with API key
headers = {
    "api_key": api_key
}

# API request
response = requests.get(url, params=params, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Process the data as needed
    for station in data['collection']:
        station_code = station['stationCode']
        station_name = station['stationName']
        rainfall_data = station['rainfall']
        
        # Process or store the rainfall data as needed
        print(f"Station Code: {station_code}, Station Name: {station_name}")
        print("Rainfall Data:", rainfall_data)
        print("-" * 50)

else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# Station Code: AN001, Station Name: Allanooka
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 307, 'period': 326.2}
# --------------------------------------------------
# Station Code: AM001, Station Name: Amelup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.2, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 304.2, 'period': 343.6}
# --------------------------------------------------
# Station Code: SH002, Station Name: Babakin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.6, 'yearToDate': 258.6, 'period': 272.2}
# --------------------------------------------------
# Station Code: BA, Station Name: Badgingarra
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 0.8, 'yearToDate': 330, 'period': 345.2}
# --------------------------------------------------
# Station Code: BP001, Station Name: Balingup
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 1.2, 'yearToDate': 577.8, 'period': 601.2}
# --------------------------------------------------
# Station Code: BE001, Station Name: Beacon
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 175.8, 'period': 178.8}
# --------------------------------------------------
# Station Code: ME004, Station Name: Belka East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 14.2, 'last14Days': 14.2, 'monthToDate': 14.2, 'yearToDate': 221, 'period': 231}
# --------------------------------------------------
# Station Code: BC001, Station Name: Bencubbin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 194, 'period': 202.4}
# --------------------------------------------------
# Station Code: BB001, Station Name: Bindi Bindi
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.4, 'last14Days': 1.4, 'monthToDate': 1.4, 'yearToDate': 245.2, 'period': 251.2}
# --------------------------------------------------
# Station Code: ER002, Station Name: Bindoo
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 138.8, 'period': 143.2}
# --------------------------------------------------
# Station Code: BX001, Station Name: Bindoon
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 452.4, 'period': 484.4}
# --------------------------------------------------
# Station Code: BI, Station Name: Binnu
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.2, 'yearToDate': 169.8, 'period': 180}
# --------------------------------------------------
# Station Code: BI002, Station Name: Binnu West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 108.8, 'period': 117.4}
# --------------------------------------------------
# Station Code: BR, Station Name: Bonnie Rock
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 178.6, 'period': 200.8}
# --------------------------------------------------
# Station Code: DB002, Station Name: Boyanup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0.2, 'monthToDate': 1.2, 'yearToDate': 553.2, 'period': 552}
# --------------------------------------------------
# Station Code: BO001, Station Name: Boyatup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 5.8, 'last14Days': 12.6, 'monthToDate': 12.6, 'yearToDate': 475.6, 'period': 591.2}
# --------------------------------------------------
# Station Code: BY001, Station Name: Bremer Bay
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.6, 'yearToDate': 444.2, 'period': 531}
# --------------------------------------------------
# Station Code: BN001, Station Name: Brookton
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 388, 'period': 399.8}
# --------------------------------------------------
# Station Code: BR010, Station Name: Broome (Skuthorpe)
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 1507, 'period': 1756.8}
# --------------------------------------------------
# Station Code: BJ, Station Name: Brunswick Junction
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 2, 'yearToDate': 681.2, 'period': 691.6}
# --------------------------------------------------
# Station Code: BT001, Station Name: Buntine West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1, 'last14Days': 1, 'monthToDate': 1, 'yearToDate': 186, 'period': 187.8}
# --------------------------------------------------
# Station Code: BK001, Station Name: Burakin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 195, 'period': 196.6}
# --------------------------------------------------
# Station Code: SB001, Station Name: Burracoppin South
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 4.2, 'last14Days': 4.2, 'monthToDate': 4.2, 'yearToDate': 240.4, 'period': 261.8}
# --------------------------------------------------
# Station Code: CE001, Station Name: Canna East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 168.2, 'period': 170.8}
# --------------------------------------------------
# Station Code: CL001, Station Name: Capel
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 569.4, 'period': 588.6}
# --------------------------------------------------
# Station Code: CE002, Station Name: Carnamah East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.6, 'yearToDate': 185.6, 'period': 194.4}
# --------------------------------------------------
# Station Code: CA, Station Name: Carnarvon 1
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 102, 'period': 102}
# --------------------------------------------------
# Station Code: CA001, Station Name: Cascade
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.2, 'last14Days': 2.4, 'monthToDate': 2.4, 'yearToDate': 273.8, 'period': 321}
# --------------------------------------------------
# Station Code: CS003, Station Name: Cascade NE
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 3.6, 'last14Days': 3.8, 'monthToDate': 3.8, 'yearToDate': 201, 'period': 248}
# --------------------------------------------------
# Station Code: CS002, Station Name: Cascade NW
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.4, 'last14Days': 4.8, 'monthToDate': 4.8, 'yearToDate': 218.4, 'period': 272.8}
# --------------------------------------------------
# Station Code: CH, Station Name: Chapman
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 241.2, 'period': 250.6}
# --------------------------------------------------
# Station Code: CN001, Station Name: Condingup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 4.4, 'last14Days': 7.4, 'monthToDate': 7.4, 'yearToDate': 503.8, 'period': 592.8}
# --------------------------------------------------
# Station Code: CP001, Station Name: Coomalbidgup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1, 'last14Days': 6.8, 'monthToDate': 6.8, 'yearToDate': 454.6, 'period': 539.4}
# --------------------------------------------------
# Station Code: CW001, Station Name: Coorow
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 199, 'period': 205.4}
# --------------------------------------------------
# Station Code: CD001, Station Name: Cordering
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 1, 'yearToDate': 419.2, 'period': 453.4}
# --------------------------------------------------
# Station Code: CO001, Station Name: Corrigin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1, 'last14Days': 1, 'monthToDate': 1, 'yearToDate': 308.8, 'period': 313}
# --------------------------------------------------
# Station Code: CO002, Station Name: Corrigin East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 0.8, 'yearToDate': 324.2, 'period': 339}
# --------------------------------------------------
# Station Code: CP002, Station Name: Cowalellup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 297.6, 'period': 366.2}
# --------------------------------------------------
# Station Code: CR001, Station Name: Cranbrook Dam 3
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0.2, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 0.4, 'last14Days': 0.8, 'monthToDate': 0.8, 'yearToDate': 128.4, 'period': 127.6}
# --------------------------------------------------
# Station Code: BCAA, Station Name: DBCA-A Portable
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': None}
# --------------------------------------------------
# Station Code: BCAB, Station Name: DBCA-B Portable
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 197.5, 'period': 197.5}
# --------------------------------------------------
# Station Code: BTSA, Station Name: DFES-A Portable
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 92.8, 'period': 125.4}
# --------------------------------------------------
# Station Code: BTSB, Station Name: DFES-B Talbot West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 480.3, 'period': 501.5}
# --------------------------------------------------
# Station Code: BTSC, Station Name: DFES-C Portable
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 146.8, 'period': 160.6}
# --------------------------------------------------
# Station Code: BTSD, Station Name: DFES-D Boorabbin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 250.7, 'period': 313.1}
# --------------------------------------------------
# Station Code: BTSE, Station Name: DFES-E Portable
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0.8, 'currentHour': 0, 'last24Hrs': 1, 'last7Days': 2, 'last14Days': 6, 'monthToDate': 8.2, 'yearToDate': 1076.1, 'period': 1776}
# --------------------------------------------------
# Station Code: BTSF, Station Name: DFES-F Portable
# Rainfall Data: {'to9AM': 0.4, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 25.4, 'last14Days': 39.6, 'monthToDate': 51.2, 'yearToDate': 1274.9, 'period': 1223.7}
# --------------------------------------------------
# Station Code: BTSG, Station Name: DFES-G Portable
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 689.7, 'period': 689.7}
# --------------------------------------------------
# Station Code: BTSI, Station Name: DFES-I Portable
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': 0}
# --------------------------------------------------
# Station Code: DG001, Station Name: Dandaragan East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 339.6, 'period': 377.2}
# --------------------------------------------------
# Station Code: DA, Station Name: Dardanup (Waterloo)
# Rainfall Data: {'to9AM': 0.8, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.8, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 1, 'yearToDate': 703.8, 'period': 711.8}
# --------------------------------------------------
# Station Code: DA002, Station Name: Dardanup 2
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.2, 'yearToDate': 670.2, 'period': 682.2}
# --------------------------------------------------
# Station Code: DK001, Station Name: Darkan
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.2, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 329.8, 'period': 356.4}
# --------------------------------------------------
# Station Code: DM001, Station Name: Denmark
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.8, 'yearToDate': 1017, 'period': 1075.4}
# --------------------------------------------------
# Station Code: DP001, Station Name: Dinninup
# Rainfall Data: {'to9AM': 0.4, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 0.4, 'last14Days': 0.4, 'monthToDate': 1.4, 'yearToDate': 414, 'period': 442.8}
# --------------------------------------------------
# Station Code: DB, Station Name: Donnybrook
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.6, 'yearToDate': 654, 'period': 667.6}
# --------------------------------------------------
# Station Code: DR001, Station Name: Dragon Rocks
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.4, 'last14Days': 2.4, 'monthToDate': 2.4, 'yearToDate': 307.2, 'period': 325}
# --------------------------------------------------
# Station Code: TS002, Station Name: Dudawa
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 190.6, 'period': 197}
# --------------------------------------------------
# Station Code: DU001, Station Name: Dumbleyung
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 280.6, 'period': 313.2}
# --------------------------------------------------
# Station Code: DU002, Station Name: Dumbleyung GRDC
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 260.8, 'period': 282.6}
# --------------------------------------------------
# Station Code: EB, Station Name: East Beverley
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.6, 'yearToDate': 454.2, 'period': 477}
# --------------------------------------------------
# Station Code: EJ001, Station Name: Ejanding
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 4.4, 'last14Days': 4.4, 'monthToDate': 4.4, 'yearToDate': 223.8, 'period': 254.2}
# --------------------------------------------------
# Station Code: EN001, Station Name: Eneabba
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.4, 'last14Days': 0.4, 'monthToDate': 0.4, 'yearToDate': 264.4, 'period': 278.6}
# --------------------------------------------------
# Station Code: ER, Station Name: Eradu 2
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 238.6, 'period': 254.4}
# --------------------------------------------------
# Station Code: ES001, Station Name: Erangy Springs
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 246, 'period': 256.4}
# --------------------------------------------------
# Station Code: ES, Station Name: Esperance Downs
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 3.6, 'last14Days': 5, 'monthToDate': 5, 'yearToDate': 496.4, 'period': 593.2}
# --------------------------------------------------
# Station Code: FL, Station Name: Floreat Park
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 672.6, 'period': 709}
# --------------------------------------------------
# Station Code: GI001, Station Name: Fouracres
# Rainfall Data: {'to9AM': 1, 'since9AM': 0.2, 'currentHour': 0, 'last24Hrs': 1.2, 'last7Days': 1.2, 'last14Days': 1.2, 'monthToDate': 1.2, 'yearToDate': 950, 'period': 1014.4}
# --------------------------------------------------
# Station Code: FR, Station Name: Frankland
# Rainfall Data: {'to9AM': 2.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 2.2, 'last7Days': 2.2, 'last14Days': 2.2, 'monthToDate': 2.2, 'yearToDate': 557.8, 'period': 604.2}
# --------------------------------------------------
# Station Code: FR002, Station Name: Frankland North
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 467.3, 'period': 467.3}
# --------------------------------------------------
# Station Code: GA001, Station Name: Gairdner
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0.4, 'monthToDate': 0.4, 'yearToDate': 364, 'period': 456.2}
# --------------------------------------------------
# Station Code: GW, Station Name: Gingin West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 486.6, 'period': 510.6}
# --------------------------------------------------
# Station Code: GE001, Station Name: Glen Eagle
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.6, 'yearToDate': 867, 'period': 905.2}
# --------------------------------------------------
# Station Code: GN002, Station Name: Gnowangerup GRDC
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 263.6, 'period': 293.2}
# --------------------------------------------------
# Station Code: KL002, Station Name: Goodlands
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 158.2, 'period': 170.8}
# --------------------------------------------------
# Station Code: GP001, Station Name: Grass Patch
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 4.6, 'last14Days': 5, 'monthToDate': 5, 'yearToDate': 224.2, 'period': 300.8}
# --------------------------------------------------
# Station Code: GU001, Station Name: Gutha West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 200.8, 'period': 211.2}
# --------------------------------------------------
# Station Code: HV, Station Name: Harvey
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.4, 'yearToDate': 853.6, 'period': 882.4}
# --------------------------------------------------
# Station Code: NA002, Station Name: Highbury East
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.4, 'last14Days': 0.4, 'monthToDate': 0.4, 'yearToDate': 316.8, 'period': 321.4}
# --------------------------------------------------
# Station Code: HR, Station Name: Holt Rock
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 266.8, 'period': 298.6}
# --------------------------------------------------
# Station Code: HY001, Station Name: Hyden
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.2, 'last14Days': 2.2, 'monthToDate': 2.2, 'yearToDate': 245.4, 'period': 262.4}
# --------------------------------------------------
# Station Code: JA001, Station Name: Jarrahdale
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.6, 'yearToDate': 854, 'period': 903}
# --------------------------------------------------
# Station Code: JA002, Station Name: Jarrahdale 2
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.6, 'yearToDate': 925, 'period': 964.4}
# --------------------------------------------------
# Station Code: JP001, Station Name: Jerdacuttup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.8, 'last14Days': 1.6, 'monthToDate': 1.6, 'yearToDate': 245.6, 'period': 314.8}
# --------------------------------------------------
# Station Code: JE, Station Name: Jerramungup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 250.2, 'period': 284.8}
# --------------------------------------------------
# Station Code: JE002, Station Name: Jerramungup Town
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 303.8, 'period': 368}
# --------------------------------------------------
# Station Code: TU002, Station Name: Jingalup
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 481, 'period': 529.8}
# --------------------------------------------------
# Station Code: JB001, Station Name: Jurien Bay
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 327, 'period': 345}
# --------------------------------------------------
# Station Code: KL, Station Name: Kalannie
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.4, 'last14Days': 1.4, 'monthToDate': 1.4, 'yearToDate': 169, 'period': 173.2}
# --------------------------------------------------
# Station Code: KARI, Station Name: Karijini
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 21, 'period': 24.4}
# --------------------------------------------------
# Station Code: KR001, Station Name: Karridale
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.4, 'yearToDate': 708.6, 'period': 746.8}
# --------------------------------------------------
# Station Code: KA, Station Name: Katanning
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 299.6, 'period': 327.2}
# --------------------------------------------------
# Station Code: KA002, Station Name: Katanning GRDC
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 333.8, 'period': 354.4}
# --------------------------------------------------
# Station Code: KA003, Station Name: Katanning NG In
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 238.2, 'period': 262.4}
# --------------------------------------------------
# Station Code: KA004, Station Name: Katanning NG Out
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 349, 'period': 377.2}
# --------------------------------------------------
# Station Code: KE001, Station Name: Kellerberrin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 6.4, 'last14Days': 6.4, 'monthToDate': 6.4, 'yearToDate': 245.6, 'period': 254.2}
# --------------------------------------------------
# Station Code: KE002, Station Name: Kellerberrin North
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 10.4, 'last14Days': 10.4, 'monthToDate': 10.4, 'yearToDate': 231.6, 'period': 249.8}
# --------------------------------------------------
# Station Code: MB002, Station Name: Kendenup West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.2, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 525, 'period': 569.6}
# --------------------------------------------------
# Station Code: BG001, Station Name: Kings Park
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 680, 'period': 714}
# --------------------------------------------------
# Station Code: KO002, Station Name: Kojaneerup South
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 1.4, 'last14Days': 2.4, 'monthToDate': 2.4, 'yearToDate': 366.2, 'period': 437.6}
# --------------------------------------------------
# Station Code: KD001, Station Name: Kondinin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.2, 'last14Days': 1.2, 'monthToDate': 1.2, 'yearToDate': 269.8, 'period': 278.6}
# --------------------------------------------------
# Station Code: KO001, Station Name: Koorda
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1, 'last14Days': 1, 'monthToDate': 1, 'yearToDate': 300.4, 'period': 335}
# --------------------------------------------------
# Station Code: KI001, Station Name: Kulin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 0.8, 'yearToDate': 303, 'period': 319.8}
# --------------------------------------------------
# Station Code: SG002, Station Name: Kumarl
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.2, 'last14Days': 16.6, 'monthToDate': 16.6, 'yearToDate': 204.8, 'period': 238.8}
# --------------------------------------------------
# Station Code: KN, Station Name: Kununurra
# Rainfall Data: {'to9AM': 2.6, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 2.6, 'last7Days': 10, 'last14Days': 49.2, 'monthToDate': 68.4, 'yearToDate': 771.2, 'period': 1137.8}
# --------------------------------------------------
# Station Code: KW001, Station Name: Kweda
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 417.4, 'period': 430.2}
# --------------------------------------------------
# Station Code: LK, Station Name: Lake King
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.4, 'last14Days': 2.6, 'monthToDate': 2.6, 'yearToDate': 336.2, 'period': 373}
# --------------------------------------------------
# Station Code: LE, Station Name: Lancelin East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 424.4, 'period': 457.8}
# --------------------------------------------------
# Station Code: LA001, Station Name: Latham
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 204.2, 'period': 209}
# --------------------------------------------------
# Station Code: LAWS, Station Name: Lawson Road
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.1, 'yearToDate': 292.7, 'period': 311}
# --------------------------------------------------
# Station Code: LG, Station Name: Logue Brook
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 720.2, 'period': 778.4}
# --------------------------------------------------
# Station Code: DN001, Station Name: Lort River
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2, 'last14Days': 2.8, 'monthToDate': 3.4, 'yearToDate': 237.8, 'period': 290.4}
# --------------------------------------------------
# Station Code: MG001, Station Name: Magenta
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1, 'last14Days': 1, 'monthToDate': 1, 'yearToDate': 269.8, 'period': 287.6}
# --------------------------------------------------
# Station Code: MA002, Station Name: Manjimup HRS
# Rainfall Data: {'to9AM': 2.8, 'since9AM': 0.2, 'currentHour': 0, 'last24Hrs': 3, 'last7Days': 3, 'last14Days': 3.2, 'monthToDate': 3.2, 'yearToDate': 935.8, 'period': 1002.4}
# --------------------------------------------------
# Station Code: MP, Station Name: Manypeaks
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.4, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 2, 'last14Days': 2, 'monthToDate': 2.4, 'yearToDate': 620, 'period': 698.6}
# --------------------------------------------------
# Station Code: MR002, Station Name: Margaret River
# Rainfall Data: {'to9AM': 2.4, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 2.4, 'last7Days': 2.4, 'last14Days': 2.4, 'monthToDate': 3.4, 'yearToDate': 970, 'period': 1004.2}
# --------------------------------------------------
# Station Code: BW001, Station Name: Marradong
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 539.2, 'period': 590.4}
# --------------------------------------------------
# Station Code: MS001, Station Name: Mayanup South
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 463, 'period': 497.8}
# --------------------------------------------------
# Station Code: MC001, Station Name: McAlinden
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 498, 'period': 513.4}
# --------------------------------------------------
# Station Code: MEAN, Station Name: Meanarra Tower
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': None}
# --------------------------------------------------
# Station Code: MN, Station Name: Meckering North
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.2, 'last14Days': 2.2, 'monthToDate': 2.2, 'yearToDate': 267.6, 'period': 282.6}
# --------------------------------------------------
# Station Code: ME, Station Name: Merredin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 0.8, 'yearToDate': 198.2, 'period': 237.8}
# --------------------------------------------------
# Station Code: ME002, Station Name: Merredin NG In
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.2, 'last14Days': 1.2, 'monthToDate': 1.2, 'yearToDate': 205.4, 'period': 242.6}
# --------------------------------------------------
# Station Code: ME003, Station Name: Merredin NG Out
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.4, 'last14Days': 1.4, 'monthToDate': 1.4, 'yearToDate': 203.4, 'period': 238.2}
# --------------------------------------------------
# Station Code: MILL, Station Name: Millstream Chichester National Park
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 464.2, 'period': 554.8}
# --------------------------------------------------
# Station Code: MX001, Station Name: Milyeannup
# Rainfall Data: {'to9AM': 1.6, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 1.6, 'last7Days': 1.6, 'last14Days': 1.8, 'monthToDate': 1.8, 'yearToDate': 897.6, 'period': 934.4}
# --------------------------------------------------
# Station Code: MI, Station Name: Mingenew
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1, 'last14Days': 1, 'monthToDate': 1, 'yearToDate': 238.6, 'period': 247.6}
# --------------------------------------------------
# Station Code: MI002, Station Name: Mingenew NW
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.4, 'last14Days': 0.4, 'monthToDate': 0.4, 'yearToDate': 179.2, 'period': 188.6}
# --------------------------------------------------
# Station Code: MIPL, Station Name: Mitchell Plateau
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': None}
# --------------------------------------------------
# Station Code: MZ, Station Name: Moora
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.4, 'last14Days': 0.4, 'monthToDate': 0.4, 'yearToDate': 229.4, 'period': 237}
# --------------------------------------------------
# Station Code: MZ002, Station Name: Moora NW
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2, 'last14Days': 2, 'monthToDate': 2, 'yearToDate': 233.6, 'period': 248.6}
# --------------------------------------------------
# Station Code: MOOR, Station Name: Moore River
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': None}
# --------------------------------------------------
# Station Code: ME005, Station Name: Moorine Rock
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.2, 'last14Days': 2.2, 'monthToDate': 2.6, 'yearToDate': 239.6, 'period': 249}
# --------------------------------------------------
# Station Code: MO, Station Name: Morawa
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 137.8, 'period': 141.2}
# --------------------------------------------------
# Station Code: MB, Station Name: Mount Barker
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.4, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 0.4, 'last14Days': 2.6, 'monthToDate': 2.6, 'yearToDate': 638.4, 'period': 714}
# --------------------------------------------------
# Station Code: MB003, Station Name: Mount Barker South
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.4, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 0.8, 'last14Days': 1.2, 'monthToDate': 1.2, 'yearToDate': 580.2, 'period': 587.4}
# --------------------------------------------------
# Station Code: BU, Station Name: Mount Buraminya
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 2.4, 'last14Days': 6.2, 'monthToDate': 6.6, 'yearToDate': 336.8, 'period': 398}
# --------------------------------------------------
# Station Code: BD, Station Name: Mount Burdett
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 5, 'last14Days': 8, 'monthToDate': 8, 'yearToDate': 342.8, 'period': 407}
# --------------------------------------------------
# Station Code: BURN, Station Name: Mount Burnside
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 2.6, 'period': 7.8}
# --------------------------------------------------
# Station Code: DALE, Station Name: Mount Dale
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': None}
# --------------------------------------------------
# Station Code: HO, Station Name: Mount Howick
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.4, 'last14Days': 5, 'monthToDate': 5, 'yearToDate': 448.8, 'period': 549.4}
# --------------------------------------------------
# Station Code: MD001, Station Name: Mount Madden East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 3.6, 'last14Days': 3.6, 'monthToDate': 3.6, 'yearToDate': 244.6, 'period': 263.6}
# --------------------------------------------------
# Station Code: BD002, Station Name: Mount Ney
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 5.2, 'last14Days': 7.6, 'monthToDate': 7.6, 'yearToDate': 232.6, 'period': 301.8}
# --------------------------------------------------
# Station Code: SOLS, Station Name: Mount Solus
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': 0}
# --------------------------------------------------
# Station Code: NB002, Station Name: Mount Walker
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 7.6, 'last14Days': 7.6, 'monthToDate': 7.6, 'yearToDate': 277.2, 'period': 280.2}
# --------------------------------------------------
# Station Code: MU001, Station Name: Mukinbudin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 0.8, 'yearToDate': 197.8, 'period': 212.4}
# --------------------------------------------------
# Station Code: MU, Station Name: Mullewa
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.4, 'last14Days': 0.4, 'monthToDate': 0.4, 'yearToDate': 233.4, 'period': 242.8}
# --------------------------------------------------
# Station Code: MP002, Station Name: Munglinup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.2, 'last14Days': 2.6, 'monthToDate': 2.6, 'yearToDate': 426.2, 'period': 497}
# --------------------------------------------------
# Station Code: SB002, Station Name: Muntadgin East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 5.4, 'last14Days': 5.4, 'monthToDate': 5.4, 'yearToDate': 254.4, 'period': 281.8}
# --------------------------------------------------
# Station Code: MK, Station Name: Muresk
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 297.6, 'period': 333.2}
# --------------------------------------------------
# Station Code: MY, Station Name: Myalup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 762.4, 'period': 789}
# --------------------------------------------------
# Station Code: NU001, Station Name: Nannup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 650.2, 'period': 690}
# --------------------------------------------------
# Station Code: NU002, Station Name: Nannup 2 (Carlotta)
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 839.8, 'period': 906.6}
# --------------------------------------------------
# Station Code: NB001, Station Name: Narembeen
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 221, 'period': 238.2}
# --------------------------------------------------
# Station Code: NA003, Station Name: Narrikup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.6, 'currentHour': 0.2, 'last24Hrs': 0.6, 'last7Days': 2.2, 'last14Days': 3, 'monthToDate': 3.2, 'yearToDate': 582.8, 'period': 661.2}
# --------------------------------------------------
# Station Code: NA001, Station Name: Narrogin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 398.4, 'period': 406}
# --------------------------------------------------
# Station Code: NN001, Station Name: New Norcia
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.2, 'last14Days': 1.2, 'monthToDate': 1.2, 'yearToDate': 403.6, 'period': 431}
# --------------------------------------------------
# Station Code: NE, Station Name: Newdegate
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.4, 'last14Days': 1.4, 'monthToDate': 1.4, 'yearToDate': 280.4, 'period': 296.4}
# --------------------------------------------------
# Station Code: KP001, Station Name: Newlands
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 684.6, 'period': 720.2}
# --------------------------------------------------
# Station Code: NO, Station Name: Northam
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.6, 'yearToDate': 246.6, 'period': 264.4}
# --------------------------------------------------
# Station Code: NW001, Station Name: Northampton West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 210.4, 'period': 223.8}
# --------------------------------------------------
# Station Code: NL001, Station Name: Northcliffe
# Rainfall Data: {'to9AM': 0.4, 'since9AM': 2.6, 'currentHour': 0, 'last24Hrs': 3, 'last7Days': 3, 'last14Days': 4, 'monthToDate': 4.4, 'yearToDate': 1191.6, 'period': 1250.4}
# --------------------------------------------------
# Station Code: NY001, Station Name: Nyabing
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 334, 'period': 350.8}
# --------------------------------------------------
# Station Code: NY002, Station Name: Nyabing GRDC
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 328.6, 'period': 372.4}
# --------------------------------------------------
# Station Code: ON002, Station Name: Ongerup GRDC
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 204.4, 'period': 241.4}
# --------------------------------------------------
# Station Code: ON001, Station Name: Ongerup North
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 254.6, 'period': 297.2}
# --------------------------------------------------
# Station Code: PD, Station Name: Pardoo
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 0.8, 'monthToDate': 0.8, 'yearToDate': 493.2, 'period': 529.8}
# --------------------------------------------------
# Station Code: PM, Station Name: Pemberton
# Rainfall Data: {'to9AM': 0.8, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.8, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 1.6, 'yearToDate': 1249.6, 'period': 1343}
# --------------------------------------------------
# Station Code: PJ001, Station Name: Perenjori
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 119.2, 'period': 121.8}
# --------------------------------------------------
# Station Code: MU002, Station Name: Pindar South
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 148, 'period': 159.4}
# --------------------------------------------------
# Station Code: PN001, Station Name: Pingaring
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.8, 'last14Days': 1.8, 'monthToDate': 1.8, 'yearToDate': 404.8, 'period': 417.2}
# --------------------------------------------------
# Station Code: PY001, Station Name: Pingelly West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 414.4, 'period': 426.2}
# --------------------------------------------------
# Station Code: PG001, Station Name: Pingrup East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 283, 'period': 311.2}
# --------------------------------------------------
# Station Code: PINJ, Station Name: Pinjar Tower
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 401.4, 'period': 422.8}
# --------------------------------------------------
# Station Code: PI001, Station Name: Pinjarra
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.2, 'yearToDate': 689.4, 'period': 745}
# --------------------------------------------------
# Station Code: PO001, Station Name: Popanyinning
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 419.6, 'period': 427}
# --------------------------------------------------
# Station Code: QD001, Station Name: Quairading
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.2, 'last14Days': 1.2, 'monthToDate': 1.2, 'yearToDate': 411.2, 'period': 432.6}
# --------------------------------------------------
# Station Code: QA001, Station Name: Qualeup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.6, 'yearToDate': 421.6, 'period': 448.2}
# --------------------------------------------------
# Station Code: DM002, Station Name: Quickup Dam
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.6, 'currentHour': 0, 'last24Hrs': 0.6, 'last7Days': 0.8, 'last14Days': 1.4, 'monthToDate': 1.8, 'yearToDate': 649.4, 'period': 647.6}
# --------------------------------------------------
# Station Code: QP001, Station Name: Quinninup
# Rainfall Data: {'to9AM': 1.4, 'since9AM': 0.8, 'currentHour': 0, 'last24Hrs': 2.2, 'last7Days': 2.2, 'last14Days': 3.2, 'monthToDate': 3.4, 'yearToDate': 897, 'period': 968.4}
# --------------------------------------------------
# Station Code: RA, Station Name: Ravensthorpe
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2, 'last14Days': 2.2, 'monthToDate': 2.2, 'yearToDate': 298.2, 'period': 325.8}
# --------------------------------------------------
# Station Code: RA002, Station Name: Ravensthorpe Dam #4
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1.2, 'last14Days': 1.6, 'monthToDate': 1.6, 'yearToDate': 145, 'period': 151.6}
# --------------------------------------------------
# Station Code: RF001, Station Name: Regans Ford
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 403.8, 'period': 426.6}
# --------------------------------------------------
# Station Code: LR001, Station Name: Ridley North
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 4, 'last14Days': 5.4, 'monthToDate': 5.4, 'yearToDate': 229.6, 'period': 296}
# --------------------------------------------------
# Station Code: ROGR, Station Name: Rolling Green
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 6.4, 'period': 6.4}
# --------------------------------------------------
# Station Code: RB001, Station Name: Rosa Brook
# Rainfall Data: {'to9AM': 0.4, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 0.4, 'last14Days': 0.4, 'monthToDate': 1.6, 'yearToDate': 863.6, 'period': 899.2}
# --------------------------------------------------
# Station Code: SG, Station Name: Salmon Gums
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.8, 'last14Days': 3.2, 'monthToDate': 3.2, 'yearToDate': 238.8, 'period': 306.4}
# --------------------------------------------------
# Station Code: SC, Station Name: Scaddan
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 5.6, 'last14Days': 6.4, 'monthToDate': 6.8, 'yearToDate': 251.2, 'period': 300.8}
# --------------------------------------------------
# Station Code: SR001, Station Name: Scott River
# Rainfall Data: {'to9AM': 0.8, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.8, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 1, 'yearToDate': 558.8, 'period': 595.4}
# --------------------------------------------------
# Station Code: SH001, Station Name: Shackleton
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 1, 'last14Days': 1, 'monthToDate': 1, 'yearToDate': 293.8, 'period': 312.6}
# --------------------------------------------------
# Station Code: SP, Station Name: South Perth
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 662, 'period': 688.2}
# --------------------------------------------------
# Station Code: SN001, Station Name: Stirlings North
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.2, 'currentHour': 0, 'last24Hrs': 0.2, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 346, 'period': 377.2}
# --------------------------------------------------
# Station Code: PL001, Station Name: Stirlings South
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.6, 'currentHour': 0, 'last24Hrs': 0.6, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.8, 'yearToDate': 472.6, 'period': 526.6}
# --------------------------------------------------
# Station Code: ST, Station Name: Styles Tower
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': None}
# --------------------------------------------------
# Station Code: TA001, Station Name: Tammin
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 3.2, 'last14Days': 3.2, 'monthToDate': 3.2, 'yearToDate': 250.4, 'period': 265.2}
# --------------------------------------------------
# Station Code: TS001, Station Name: Three Springs
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2.2, 'last14Days': 2.2, 'monthToDate': 2.2, 'yearToDate': 180.2, 'period': 184.8}
# --------------------------------------------------
# Station Code: THUN, Station Name: Thundelarra Station
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 0, 'period': None}
# --------------------------------------------------
# Station Code: WI, Station Name: Tincurrin
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 313.2, 'period': 323.8}
# --------------------------------------------------
# Station Code: TB001, Station Name: Tone Bridge
# Rainfall Data: {'to9AM': 0.6, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.6, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.6, 'yearToDate': 492.6, 'period': 528.6}
# --------------------------------------------------
# Station Code: TW001, Station Name: Trayning West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.6, 'yearToDate': 288.4, 'period': 333}
# --------------------------------------------------
# Station Code: TU003, Station Name: Tunney West
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 432, 'period': 465.4}
# --------------------------------------------------
# Station Code: VA, Station Name: Vasse
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 2, 'yearToDate': 672.8, 'period': 686.6}
# --------------------------------------------------
# Station Code: WA001, Station Name: Wagin
# Rainfall Data: {'to9AM': 0.4, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 1.4, 'last14Days': 1.4, 'monthToDate': 1.4, 'yearToDate': 297.6, 'period': 328.4}
# --------------------------------------------------
# Station Code: WN, Station Name: Wanneroo
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 540.2, 'period': 574}
# --------------------------------------------------
# Station Code: WR, Station Name: Waroona
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.2, 'yearToDate': 606.8, 'period': 641.6}
# --------------------------------------------------
# Station Code: ML001, Station Name: Warradarge East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 310, 'period': 324.8}
# --------------------------------------------------
# Station Code: WO001, Station Name: Watheroo
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.6, 'last14Days': 0.6, 'monthToDate': 0.6, 'yearToDate': 248.4, 'period': 255.4}
# --------------------------------------------------
# Station Code: WT001, Station Name: Wattleup
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 622.8, 'period': 655.4}
# --------------------------------------------------
# Station Code: WE, Station Name: Wellstead
# Rainfall Data: {'to9AM': 0, 'since9AM': 0.4, 'currentHour': 0, 'last24Hrs': 0.4, 'last7Days': 0.4, 'last14Days': 1.2, 'monthToDate': 1.2, 'yearToDate': 280, 'period': 403.8}
# --------------------------------------------------
# Station Code: WR001, Station Name: West River
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 1, 'monthToDate': 1, 'yearToDate': 241.2, 'period': 303.4}
# --------------------------------------------------
# Station Code: WS001, Station Name: Westonia
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 214.6, 'period': 259.8}
# --------------------------------------------------
# Station Code: EW, Station Name: Wickepin East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 291.2, 'period': 305.4}
# --------------------------------------------------
# Station Code: WI002, Station Name: Wickepin North
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 322.4, 'period': 336.6}
# --------------------------------------------------
# Station Code: WL001, Station Name: Williams
# Rainfall Data: {'to9AM': 0.8, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.8, 'last14Days': 0.8, 'monthToDate': 0.8, 'yearToDate': 413.2, 'period': 445}
# --------------------------------------------------
# Station Code: MR001, Station Name: Wilyabrup
# Rainfall Data: {'to9AM': 0.2, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 1.8, 'yearToDate': 859.2, 'period': 880.4}
# --------------------------------------------------
# Station Code: WH, Station Name: Wongan Hills
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 2, 'last14Days': 2, 'monthToDate': 2, 'yearToDate': 237.6, 'period': 260.6}
# --------------------------------------------------
# Station Code: TW002, Station Name: Wongoondy
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 188.8, 'period': 194.4}
# --------------------------------------------------
# Station Code: WD001, Station Name: Woodanilling
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0.2, 'yearToDate': 326, 'period': 348.2}
# --------------------------------------------------
# Station Code: MA003, Station Name: Yanmah
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 903.6, 'period': 965.6}
# --------------------------------------------------
# Station Code: YERR, Station Name: Yerramin
# Rainfall Data: {'to9AM': None, 'since9AM': None, 'currentHour': None, 'last24Hrs': None, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 280.5, 'period': 280.5}
# --------------------------------------------------
# Station Code: YS, Station Name: Yilgarn
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 5.6, 'last14Days': 5.6, 'monthToDate': 5.6, 'yearToDate': 237.4, 'period': 246.8}
# --------------------------------------------------
# Station Code: YE001, Station Name: York East
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0.2, 'last14Days': 0.2, 'monthToDate': 0.2, 'yearToDate': 344.6, 'period': 372.2}
# --------------------------------------------------
# Station Code: YU001, Station Name: Yuna
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 258.8, 'period': 281}
# --------------------------------------------------
# Station Code: YU002, Station Name: Yuna NE
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': None, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 196.8, 'period': 218.8}
# --------------------------------------------------
# Station Code: YU003, Station Name: Yuna North
# Rainfall Data: {'to9AM': 0, 'since9AM': 0, 'currentHour': 0, 'last24Hrs': 0, 'last7Days': 0, 'last14Days': 0, 'monthToDate': 0, 'yearToDate': 122.6, 'period': 138.2}
# --------------------------------------------------

# %%
# Create an empty list to store dataframes
dfs = []

# Process the data as needed
for station in data['collection']:
    station_code = station['stationCode']
    station_name = station['stationName']
    rainfall_data = station['rainfall']
    date_str = station['dateTime']

    # Extract year from the date string (assuming it's in 'YYYY-MM-DD' format)
    year_data = int(date_str.split('-')[0])

    # Only consider data for the year 2023
    if year_data == 2023:
        # Create a dataframe for the current station
        station_df = pd.DataFrame({
            'Station Code': [station_code],
            'Station Name': [station_name],
            'Year': [year_data],
            'To 9 AM': [rainfall_data['to9AM']],
            'Since 9 AM': [rainfall_data['since9AM']],
            'Current Hour': [rainfall_data['currentHour']],
            'Last 24 Hrs': [rainfall_data['last24Hrs']],
            'Last 7 Days': [rainfall_data['last7Days']],
            'Last 14 Days': [rainfall_data['last14Days']],
            'Month to Date': [rainfall_data['monthToDate']],
            'Year to Date': [rainfall_data['yearToDate']],
            'Period': [rainfall_data['period']]
        })

        # Append the dataframe to the list
        dfs.append(station_df)

# Concatenate all dataframes into a single dataframe
rainfall_df = pd.concat(dfs, ignore_index=True)

# Display the DataFrame
rainfall_df
# Out:
#     Station Code Station Name  Year To 9 AM Since 9 AM Current Hour  \
# 0          AN001    Allanooka  2023       0          0            0
# 1          AM001       Amelup  2023       0        0.2            0
# 2          SH002      Babakin  2023       0          0            0
# 3             BA  Badgingarra  2023       0          0            0
# 4          BP001     Balingup  2023     0.2          0            0
# ..           ...          ...   ...     ...        ...          ...
# 214           YS      Yilgarn  2023       0          0            0
# 215        YE001    York East  2023       0          0            0
# 216        YU001         Yuna  2023       0          0            0
# 217        YU002      Yuna NE  2023       0          0         None
# 218        YU003   Yuna North  2023       0          0            0
#
#     Last 24 Hrs  Last 7 Days  Last 14 Days  Month to Date  Year to Date Period
# 0             0          0.0           0.0            0.0         307.0  326.2
# 1           0.2          0.2           0.2            0.2         304.2  343.6
# 2             0          0.6           0.6            0.6         258.6  272.2
# 3             0          0.8           0.8            0.8         330.0  345.2
# 4           0.2          0.2           0.2            1.2         577.8  601.2
# ..          ...          ...           ...            ...           ...    ...
# 214           0          5.6           5.6            5.6         237.4  246.8
# 215           0          0.2           0.2            0.2         344.6  372.2
# 216           0          0.0           0.0            0.0         258.8    281
# 217           0          0.0           0.0            0.0         196.8  218.8
# 218           0          0.0           0.0            0.0         122.6  138.2
#
# [219 rows x 12 columns]

# %%
# Drop Current Hour column
rainfall_df.drop(columns=['Current Hour'], inplace = True)
rainfall_df
# Out:
#     Station Code Station Name  Year To 9 AM Since 9 AM Last 24 Hrs  \
# 0          AN001    Allanooka  2023       0          0           0
# 1          AM001       Amelup  2023       0        0.2         0.2
# 2          SH002      Babakin  2023       0          0           0
# 3             BA  Badgingarra  2023       0          0           0
# 4          BP001     Balingup  2023     0.2          0         0.2
# ..           ...          ...   ...     ...        ...         ...
# 214           YS      Yilgarn  2023       0          0           0
# 215        YE001    York East  2023       0          0           0
# 216        YU001         Yuna  2023       0          0           0
# 217        YU002      Yuna NE  2023       0          0           0
# 218        YU003   Yuna North  2023       0          0           0
#
#      Last 7 Days  Last 14 Days  Month to Date  Year to Date Period
# 0            0.0           0.0            0.0         307.0  326.2
# 1            0.2           0.2            0.2         304.2  343.6
# 2            0.6           0.6            0.6         258.6  272.2
# 3            0.8           0.8            0.8         330.0  345.2
# 4            0.2           0.2            1.2         577.8  601.2
# ..           ...           ...            ...           ...    ...
# 214          5.6           5.6            5.6         237.4  246.8
# 215          0.2           0.2            0.2         344.6  372.2
# 216          0.0           0.0            0.0         258.8    281
# 217          0.0           0.0            0.0         196.8  218.8
# 218          0.0           0.0            0.0         122.6  138.2
#
# [219 rows x 11 columns]

# %%
# Remove rows with any missing value
rainfall_df = rainfall_df.dropna()
rainfall_df
# Out:
#     Station Code Station Name  Year To 9 AM Since 9 AM Last 24 Hrs  \
# 0          AN001    Allanooka  2023       0          0           0
# 1          AM001       Amelup  2023       0        0.2         0.2
# 2          SH002      Babakin  2023       0          0           0
# 3             BA  Badgingarra  2023       0          0           0
# 4          BP001     Balingup  2023     0.2          0         0.2
# ..           ...          ...   ...     ...        ...         ...
# 214           YS      Yilgarn  2023       0          0           0
# 215        YE001    York East  2023       0          0           0
# 216        YU001         Yuna  2023       0          0           0
# 217        YU002      Yuna NE  2023       0          0           0
# 218        YU003   Yuna North  2023       0          0           0
#
#      Last 7 Days  Last 14 Days  Month to Date  Year to Date Period
# 0            0.0           0.0            0.0         307.0  326.2
# 1            0.2           0.2            0.2         304.2  343.6
# 2            0.6           0.6            0.6         258.6  272.2
# 3            0.8           0.8            0.8         330.0  345.2
# 4            0.2           0.2            1.2         577.8  601.2
# ..           ...           ...            ...           ...    ...
# 214          5.6           5.6            5.6         237.4  246.8
# 215          0.2           0.2            0.2         344.6  372.2
# 216          0.0           0.0            0.0         258.8    281
# 217          0.0           0.0            0.0         196.8  218.8
# 218          0.0           0.0            0.0         122.6  138.2
#
# [208 rows x 11 columns]

# %%
rainfall_df.to_csv('Resources/rainfall_data.csv')
